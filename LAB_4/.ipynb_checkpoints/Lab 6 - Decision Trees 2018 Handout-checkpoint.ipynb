# %% [markdown]
# <table>
#     <tr><td> <b>Group</b> </td><td>BML36</td></tr>
#     <tr><td> <b>Names</b> </td><td>Thibault Douzon</td></tr>
#     <tr><td> <b></b> </td><td>Rajavarman Mathivanan</td></tr>
# </table>

# %%
#%matplotlib inline
import numpy as np
import operator
import pylab
from matplotlib import pyplot as plt

pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %% [markdown]
# # Decision Trees
#
# In this lab, we will implement the C4.5 algorithm for classification with decision trees. Please make sure that you read the complete description and code below.

# %% [markdown]
# ## Data
#
# Let's start by loading the datasets that we will be working with. The ```mushroom``` dataset is a dataset describing the features of different species of mushrooms, and the goal is to derive simple rules to predict whether a species is poisonous or not.

# %%
# This code is given
data = np.load("uci-mushrooms.npz")
# data = np.load("hiv.npz")
print(data.keys())

d = data['inputs']
l = data['targets']
fname = data['feature_names']
print(fname)
# Out:
# KeysView(<numpy.lib.npyio.NpzFile object at 0x00000180B2FA44A8>)
# [b'cap-shape' b'cap-surface' b'cap-colour' b'bruises?' b'odour'
#  b'gill-attachment' b'gill-spacing' b'gill-size' b'gill-colour'
#  b'stalk-shape' b'stalk-root' b'stalk-surface-above-ring'
#  b'stalk-surface-below-ring' b'stalk-colour-above-ring'
#  b'stalk colour-below-ring' b'veil type' b'veil colour' b'Number-of-rings'
#  b'Type-of-ring' b'spore-print-colour' b'population' b'habitat']

# %% [markdown]
# ## Helper functions
#
# Here are a few functions to deal with categorical labels

# %%
# This code is given

def listValues(inputlist):
    """List the possible values of a given feature in a dataset"""
    values = set([])
    for x in inputlist:
        values.add(x)
    return list(values)

def countLabels(labelList):
    """Count how often each individual label is repeated in the list"""
    counts = {}
    for x in labelList:
        if x not in counts:
            counts[x] = 1
        else:
            counts[x] += 1
    return counts

def majorityLabel(labelList):
    """Return the most common label in a list"""    
    counts = countLabels(labelList)
#    print()"Majority label:", counts)
    return max(counts.items(), key=operator.itemgetter(1))[0]


print(listValues(l))
print(listValues(d[:,0]))
print(countLabels(l))
print(majorityLabel(d[:,1]))
# Out:
# [b'POISONOUS', b'EDIBLE']
# [b'CONVEX', b'CONICAL', b'KNOBBED', b'SUNKEN', b'BELL', b'FLAT']
# {b'POISONOUS': 3928, b'EDIBLE': 4488}
# b'SCALY'

# %% [markdown]
# ## Computing the entropy of a list of categorical values
#
# The decision tree makes its decision based on decision nodes, and these nodes are evaluated based on information gain they provide on the training data. Information gain is computed as
# $$
# IG = H(parent) - \sum_j \frac{N_j}{N} H(child=j)
# $$
# the entropy of the data associated with the parent, minus the weighted entropy of the data-subsets associated with the chidlren
#
# **question 1 [5 credits]]** Implement a helper function that computes the entropy of a set of categorical labels

# %%
"""0.9968038285222955"""
# Answer to Question 1
#ANSQ1
def entropy(labelList):
    e = 0
    for label, count in countLabels(labelList).items():
        e -= count/len(labelList)*np.log2(count/len(labelList))
    return e
        
print(entropy(l))
               
# Comment: it is possible for the entropy to be larger than one, if you 
# consider distributions over more than 2 values. Don't panic :-)
#/ANSQ1
# Out:
# 0.7344929878347641

# %% [markdown]
# ## Implementing the tree
#
# Below, you are given the code to make a decision tree, train it and classify datapoints using binary decision nodes based on categorical variables.
#
# The implementation creates ```Node``` objects, which provide three methods: ```classify```, which returns the predicted label for a datapoint, and ```entropy``` and ```informationGain```, which are used in training. How ```classify``` does its work depends on the type of node, and is implemented in the derived classes.
#
# ```Leaf``` nodes return a fixed classification result that does not depend on the datapoint at all: the classification is defined by the path that was traveled through the tree to reach that node (and, of course, that path depends on the value of the datapoint). ```Leaf``` nodes simply return the majority label of the training data that is associated with them. All other nodes allow have children, and their ```classify``` method consists of deciding which child to select to classify the datapoint. A first implementation of such a node is the ```BinaryNode```, which makes a binary decision on which of its two children should be responsible for the further classification.
#
# Each ```Node```'s constructor is given training data which is used to optimise the ```Node```'s classification strategy. ```Leaf``` nodes use this data to select the majority class, ```BinaryNodes``` select the most informative feature and that feature's most informative value in their data. When ```classify```ing a new datapoint, they select which child should perform the classification based on whether or not the corresponding feature of the datapoint equals that value, or not.

# %%
# This code is given

class Node:
    """Abstract class for a decision tree node"""
    def classify(self, datapoint):
        """Return the classification label for the given datapoint"""
        raise Exception("Not Implemented")        
    def entropy(self):
        """Return the entropy of the training data associated with this node"""
    def informationGain(self):
        """Return the information gain of this node on the training data """
        raise Exception("Not Implemented by derived class")

class Leaf(Node):
    """Leaf node, i.e., a node with no children"""
    def __init__(self,inputs, targets):
#        print "Inputs, targets:", inputs.shape, targets.shape
        
        self.v = majorityLabel(targets)
        self.inputs = inputs
        self.targets = targets
        self.children = None
        self.H = entropy(targets)
        
    def entropy(self):
        """Return the entropy of the training data associated with this node"""
        return self.H
    
    def informationGain(self):
        """No splitting of the data, so no information gain"""
        return 0.
    
    def classify(self,datapoint):
        """Return the majority class for this node (and ignore the actual value of the datapoint)"""
        return self.v
    
    def __str__(self): 
        """Used for printing trees"""
        return "\t\t\t=> %s [Leaf]" % (self.v)
    
class BinaryNode(Node):
    """Make a decision based on whether a given feature equals a specific value, or not"""
    def __init__(self, inputs, targets, feature):
        self.feature = feature
        self.value   = None
        self.IG      = 0.0
        self.H       = entropy(targets)                     # Entropy of unsplit data
        self.inputs  = inputs
        self.targets = targets
        N = float(targets.size)                             # Total number of datapoints

        for value in listValues(inputs[:,feature]):         # Go through all possible values for the given feature
            indicesTrue  = inputs[:,feature]==value         # Split the training data based on that feature/value
            indicesFalse = inputs[:,feature]!=value

            if indicesTrue.all() or indicesFalse.all():     # If none (or all) datapoints have the same value for that feature                  
                continue                                    # ... keep going

            children = [ Leaf(inputs[indicesTrue,:], targets[indicesTrue]),    # Temporarily create children
                         Leaf(inputs[indicesFalse,:], targets[indicesFalse]) ] # based on this split
            conditions = [ "%s==%s" % (fname[feature], value), "%s!=%s" % (fname[feature], value) ] # (for printing)

            Nt = float(children[0].targets.size)        # N.o. datapoints in True condition
            Nf = float(children[1].targets.size)        # N.o. datapoints in False condition
            pt = Nt/N
            pf = Nf/N
            ig = self.H - pt * children[0].entropy() - pf * children[1].entropy() # Compute the information gain 
                                                        # with the temporary children
            if ig > self.IG:                            # Check whether that information gain was better than what we had
                self.value = value                      # and if so, update the node and make those children permanent 
                self.IG = ig
                self.children = children
                self.conditions = conditions
    
    def entropy(self):
        return self.H
    
    def informationGain(self):
        """Return the entropy gain of splitting the given data according to 
        the specified feature and value"""
        return self.IG
    
    def classify(self, x):
        if x[self.feature] == self.value:
            return self.children[0].classify(x)
        else:
            return self.children[1].classify(x)
        
    def __str__(self):
        return " => Binary decision: '%s =?= %s'" % (fname[self.feature], self.value )

# %%
# This code implements the C4.5 training algorithm for decision trees.
# It is given BUT MUST BE MODIFIED! (Question 2)

# Don't worry too much about the following line, it'll come in handy later when 
# we work with heterogeneous features 
allBinary = [ BinaryNode for i in range(d[0].size) ] # all features require Binary Nodes

def c45(inputs, targets, featureType = allBinary, minSize=0):
    """Implement the C4.5 training algorithm for a classification tree"""
    ig = 0.      # Initialise the information gain as 0
    res = None   # Keep track of the best feature so far
    for feature in range(inputs.shape[1]): # Cycle through all possible features
        n = featureType[feature](inputs,targets,feature) # Create a Node of the right type for that feature
        if n.informationGain() > ig: # If that node is better than what we'd found until now, 
            ig = n.informationGain() # keep that node
            res = n
    if not res: # IF no interesting feature was found for this data, return None
#        print "WARNING: No informative feature found" # Comment this out for more verbose output
        return res
    for i in range(len(res.children)): # Now go through the children of the best node we've created
        if res.children[i].entropy() > 0.: # If that child can still be split up
            c = c45(res.children[i].inputs, res.children[i].targets, featureType, minSize) # recursively try to split it up
            if c: # if splitting it up was successful (return value is not None)
                res.children[i]=c # update the child with the created subtree
    return res


root = c45(d,l)
# Out:
# b'POISONOUS' 3928
# b'EDIBLE' 4488
# b'POISONOUS' 1712
# b'EDIBLE' 2084
# b'POISONOUS' 2216
# b'EDIBLE' 2404
# b'POISONOUS' 4
# b'POISONOUS' 3924
# b'EDIBLE' 4488
# b'POISONOUS' 604
# b'EDIBLE' 236
# b'POISONOUS' 3324
# b'EDIBLE' 4252
# b'EDIBLE' 32
# b'POISONOUS' 3928
# b'EDIBLE' 4456
# b'POISONOUS' 48
# b'EDIBLE' 404
# b'POISONOUS' 3880
# b'EDIBLE' 4084
# b'POISONOUS' 1560
# b'EDIBLE' 1732
# b'POISONOUS' 2368
# b'EDIBLE' 2756
# b'POISONOUS' 3928
# b'EDIBLE' 4488
# b'POISONOUS' 4
# b'POISONOUS' 3924
# b'EDIBLE' 4488
# b'POISONOUS' 760
# b'EDIBLE' 1700
# b'POISONOUS' 3168
# b'EDIBLE' 2788
# b'POISONOUS' 1412
# b'EDIBLE' 1272
# b'POISONOUS' 2516
# b'EDIBLE' 3216
# b'POISONOUS' 1752
# b'EDIBLE' 1516
# b'POISONOUS' 2176
# b'EDIBLE' 2972
# b'POISONOUS' 3928
# b'EDIBLE' 4488
# b'POISONOUS' 120
# b'EDIBLE' 48
# b'POISONOUS' 3808
# b'EDIBLE' 4440
# b'POISONOUS' 12
# b'EDIBLE' 32
# b'POISONOUS' 3916
# b'EDIBLE' 4456
# b'POISONOUS' 320
# b'EDIBLE' 720
# b'POISONOUS' 3608
# b'EDIBLE' 3768
# b'POISONOUS' 88
# b'EDIBLE' 56
# b'POISONOUS' 3840
# b'EDIBLE' 4432
# b'POISONOUS' 544
# b'EDIBLE' 96
# b'POISONOUS' 272
# b'POISONOUS' 272
# b'EDIBLE' 96
# b'POISONOUS' 272
# b'EDIBLE' 96
# b'POISONOUS' 272
# b'POISONOUS' 544
# b'EDIBLE' 96
# b'EDIBLE' 96
# b'POISONOUS' 544
# b'POISONOUS' 272
# b'POISONOUS' 272
# b'EDIBLE' 96
# b'POISONOUS' 272
# b'POISONOUS' 272
# b'EDIBLE' 96

# %%
"""
+->   => Binary decision: 'b'odour' =?= b'NONE''
   +-> b'odour'==b'NONE'  => Binary decision: 'b'spore-print-colour' =?= b'GREEN''
   |  +-> b'spore-print-colour'==b'GREEN' 			=> b'POISONOUS' [Leaf]
   |  +-> b'spore-print-colour'!=b'GREEN'  => Binary decision: 'b'stalk-surface-below-ring' =?= b'SCALY''
   |     +-> b'stalk-surface-below-ring'==b'SCALY'  => Binary decision: 'b'gill-size' =?= b'BROAD''
   |     |  +-> b'gill-size'==b'BROAD' 			=> b'EDIBLE' [Leaf]
   |     |  +-> b'gill-size'!=b'BROAD' 			=> b'POISONOUS' [Leaf]
   |     +-> b'stalk-surface-below-ring'!=b'SCALY'  => Binary decision: 'b'cap-surface' =?= b'GROOVES''
   |        +-> b'cap-surface'==b'GROOVES' 			=> b'POISONOUS' [Leaf]
   |        +-> b'cap-surface'!=b'GROOVES'  => Binary decision: 'b'gill-size' =?= b'BROAD''
   |           +-> b'gill-size'==b'BROAD' 			=> b'EDIBLE' [Leaf]
   |           +-> b'gill-size'!=b'BROAD'  => Binary decision: 'b'bruises?' =?= b'BRUISES''
   |              +-> b'bruises?'==b'BRUISES' 			=> b'POISONOUS' [Leaf]
   |              +-> b'bruises?'!=b'BRUISES' 			=> b'EDIBLE' [Leaf]
   +-> b'odour'!=b'NONE'  => Binary decision: 'b'bruises?' =?= b'BRUISES''
      +-> b'bruises?'==b'BRUISES'  => Binary decision: 'b'stalk-root' =?= b'CLUB''
      |  +-> b'stalk-root'==b'CLUB' 			=> b'EDIBLE' [Leaf]
      |  +-> b'stalk-root'!=b'CLUB'  => Binary decision: 'b'stalk-root' =?= b'ROOTED''
      |     +-> b'stalk-root'==b'ROOTED' 			=> b'EDIBLE' [Leaf]
      |     +-> b'stalk-root'!=b'ROOTED'  => Binary decision: 'b'gill-spacing' =?= b'CLOSE''
      |        +-> b'gill-spacing'==b'CLOSE' 			=> b'POISONOUS' [Leaf]
      |        +-> b'gill-spacing'!=b'CLOSE' 			=> b'EDIBLE' [Leaf]
      +-> b'bruises?'!=b'BRUISES' 			=> b'POISONOUS' [Leaf]
"""

# This code is given

def prettyPrint(tree, cond="", dlist = [True]):
    indent = ""
    for d in dlist[:-1]:
        indent += "   " if d else "|  "
    print(indent + "+-> " + cond + " " + tree.__str__())
    if tree.children:
        for cond,cld in zip(tree.conditions[:-1],tree.children[:-1]):
            prettyPrint(cld,cond,dlist + [ False ])
        prettyPrint(tree.children[-1], tree.conditions[-1], dlist+[ True ])

    

prettyPrint(root)
# Out:
# +->   => Binary decision: 'b'odour' =?= b'NONE''
#    +-> b'odour'==b'NONE'  => Binary decision: 'b'spore-print-colour' =?= b'GREEN''
#    |  +-> b'spore-print-colour'==b'GREEN' 			=> b'POISONOUS' [Leaf]
#    |  +-> b'spore-print-colour'!=b'GREEN'  => Binary decision: 'b'stalk-surface-below-ring' =?= b'SCALY''
#    |     +-> b'stalk-surface-below-ring'==b'SCALY'  => Binary decision: 'b'gill-size' =?= b'BROAD''
#    |     |  +-> b'gill-size'==b'BROAD' 			=> b'EDIBLE' [Leaf]
#    |     |  +-> b'gill-size'!=b'BROAD' 			=> b'POISONOUS' [Leaf]
#    |     +-> b'stalk-surface-below-ring'!=b'SCALY'  => Binary decision: 'b'cap-surface' =?= b'GROOVES''
#    |        +-> b'cap-surface'==b'GROOVES' 			=> b'POISONOUS' [Leaf]
#    |        +-> b'cap-surface'!=b'GROOVES'  => Binary decision: 'b'gill-size' =?= b'BROAD''
#    |           +-> b'gill-size'==b'BROAD' 			=> b'EDIBLE' [Leaf]
#    |           +-> b'gill-size'!=b'BROAD'  => Binary decision: 'b'bruises?' =?= b'NO''
#    |              +-> b'bruises?'==b'NO' 			=> b'EDIBLE' [Leaf]
#    |              +-> b'bruises?'!=b'NO' 			=> b'POISONOUS' [Leaf]
#    +-> b'odour'!=b'NONE'  => Binary decision: 'b'bruises?' =?= b'NO''
#       +-> b'bruises?'==b'NO' 			=> b'POISONOUS' [Leaf]
#       +-> b'bruises?'!=b'NO'  => Binary decision: 'b'stalk-root' =?= b'CLUB''
#          +-> b'stalk-root'==b'CLUB' 			=> b'EDIBLE' [Leaf]
#          +-> b'stalk-root'!=b'CLUB'  => Binary decision: 'b'stalk-root' =?= b'ROOTED''
#             +-> b'stalk-root'==b'ROOTED' 			=> b'EDIBLE' [Leaf]
#             +-> b'stalk-root'!=b'ROOTED'  => Binary decision: 'b'gill-spacing' =?= b'CROWDED''
#                +-> b'gill-spacing'==b'CROWDED' 			=> b'EDIBLE' [Leaf]
#                +-> b'gill-spacing'!=b'CROWDED' 			=> b'POISONOUS' [Leaf]

# %% [markdown]
# # Training
#
# The code above trains a decision tree.
#
# **Question 2 [5 credits]** Modify the training function provided above to stop splitting nodes when the corresponding training data contains less than ```minSize``` datapoints, where ```minSize``` is a parameter to the function. Split the data into 80\% train and 20\% test, and use 5-fold cross-validation on the training set to find a good value for this parameter (You can use external libraries to split up the data if that's easier). Then report the confusion matrix, precision, recall and accuracy that you obtain on the test set.

# %%
# Answer to Q2
#ANSQ2
import random
import sklearn.model_selection as skms


data = np.load("hiv.npz")
d = data["inputs"]
l = data["targets"]
fname = [ "feature-%d" % x for x in range(d.shape[1]) ]


allBinary = [ BinaryNode for i in range(d[0].size) ] # all features require Binary Nodes

def c45(inputs, targets, featureType = allBinary, minSize=0):
    #Copy-paste the previous code for c45 here, and modify it.
    """Implement the C4.5 training algorithm for a classification tree"""
    ig = 0.      # Initialise the information gain as 0
    res = None   # Keep track of the best feature so far
    for feature in range(inputs.shape[1]): # Cycle through all possible features
        n = featureType[feature](inputs,targets,feature) # Create a Node of the right type for that feature
        if n.informationGain() > ig: # If that node is better than what we'd found until now, 
            ig = n.informationGain() # keep that node
            res = n
    if not res: # IF no interesting feature was found for this data, return None
#        print "WARNING: No informative feature found" # Comment this out for more verbose output
        return res
    for i in range(len(res.children)): # Now go through the children of the best node we've created
        if res.children[i].entropy() > 0. and res.children[i].targets.size >= minSize: # If that child can still be split up
            c = c45(res.children[i].inputs, res.children[i].targets, featureType, minSize) # recursively try to split it up
            if c: # if splitting it up was successful (return value is not None)
                res.children[i]=c # update the child with the created subtree
    return res

# Function that divide data and labels in 2 sets, that approximately follow prop proportion
def divide_set(data, labels, prop):
    # 0 ≤ prop ≤ 1 is the proportion of items in the training set
    d_training = []
    l_training = []

    d_testing = []
    l_testing = []
    for x,c in zip(data, labels):
        # random number
        rnd = random.random()
        if rnd < prop:
            d_training += [x]
            l_training += [c]
        else:
            d_testing += [x]
            l_testing += [c]
            
    return np.array(d_training), np.array(l_training), np.array(d_testing), np.array(l_testing)


# prettyPrint(root)

# Shuffle data and labels
z = list(zip(d, l))
random.shuffle(z)
d, l = zip(*z)
d, l = np.array(d), np.array(l)

# Split in train & test with proportion of 0.8
d_train, l_train, d_test, l_test = divide_set(d, l, 0.8)

KCV = skms.KFold(5)

min_size_l = list(range(0, 501, 50))
acc_ll = [[] for _ in min_size_l]
prec_ll = [[] for _ in min_size_l]
recall_ll = [[] for _ in min_size_l]


for i,min_size in enumerate(min_size_l):
    print("Doing size {}".format(min_size))
    # For each split in KCV:
    for (i_train, i_validate) in KCV.split(d_train):
        # train on training data
        root = c45(d_train[i_train, :],l_train[i_train], minSize=min_size)

        # query on validate data
        prediction = [root.classify(x) for x in d_train[i_validate]]
        actual = [x for x in l_train[i_validate]]

        # 
        accuracy = len([1 for x, y in zip(prediction, actual) if x==y])/len(prediction)
        acc_ll[i] += [accuracy] # acc_ll[i].add(accuracy)
        
        TP = sum([1 if x==b'1' and y==b'1' else 0 for x, y in zip(prediction, actual)])
        TN = sum([1 if x==b'-1' and y==b'-1' else 0 for x, y in zip(prediction, actual)])
        FP = sum([1 if x==b'1' and y==b'-1' else 0 for x, y in zip(prediction, actual)])
        FN = sum([1 if x==b'-1' and y==b'1' else 0 for x, y in zip(prediction, actual)])
        if TP+FP==0: precision=0
        else: precision = (TP)/(TP+FP)
        if TP+FN==0: recall=0
        else: recall = (TP)/(TP+FN)
        
        prec_ll[i] += [precision]
        recall_ll[i] += [recall]

acc_ll = np.array(acc_ll)
prec_ll = np.array(prec_ll)
recall_ll = np.array(recall_ll)
        
print(acc_ll)
acc_mean_l = [acc_ll[i].mean() for i in range(len(min_size_l))]
prec_mean_l = [prec_ll[i].mean() for i in range(len(min_size_l))]
recall_mean_l = [recall_ll[i].mean() for i in range(len(min_size_l))]

plt.plot(min_size_l, acc_mean_l, 'b')
plt.plot(min_size_l, prec_mean_l, 'g')
plt.plot(min_size_l, recall_mean_l, 'r')

# Selecting the best min_size:
min_size_l = np.array(min_size_l)
min_size = min_size_l[recall_mean_l.index(max(recall_mean_l))]
print('Size selected is {}'.format(min_size))

root = c45(d_train, l_train, minSize=min_size)

prediction = [root.classify(x) for x in d_test]
actual = [x for x in l_test]

# Confusion matrix:
TP = sum([1 if x==b'1' and y==b'1' else 0 for x, y in zip(prediction, actual)])
TN = sum([1 if x==b'-1' and y==b'-1' else 0 for x, y in zip(prediction, actual)])
FP = sum([1 if x==b'1' and y==b'-1' else 0 for x, y in zip(prediction, actual)])
FN = sum([1 if x==b'-1' and y==b'1' else 0 for x, y in zip(prediction, actual)])

print(TP,FP,FN,TN, len(d_test))
assert(TP+TN+FP+FN == len(d_test))
# we select accuracy as our optimization goal
accuracy = (TP+TN)/len(d_test)

if TP+FP==0: precision=0
else: precision = (TP)/(TP+FP)
if TP+FN==0: recall=0
else: recall = (TP)/(TP+FN)

print("  |\t1\t|\t-1")
print("1 |\t{}  |\t{}".format(TP, FP))
print("-1|\t{}  |\t{}".format(FN, TN))

#/ANSQ2
# Out:
# Doing size 0
# Doing size 50

# %% [markdown]
# ### Continuous values
#
# Until now, we have only dealt with categorical features. In the next part of the lab, you will deal with mixed categorical and continuous features.
#
# One way to deal with continuous features is to split the dataset based on whether the feature is larger than a certain threshold, or not. The number of possible threshold values to consider is, of course, infinite in theory, but when deciding what the threshold value should be, based on a training dataset, only threshold values that will result in a different classification of those training examples matter: those are values that are smaller than one datapoint's feature value and larger than another's. Moreover, when considering a threshold in between two feature values, any value of the threshold in that range will result in the same classification, but to maximise generalisation it makes sense to maximise the margin: that is, to take a threshold value that is in the middle between the two.
#
# Also note that it only makes sense to consider ranges of feature values that are disjoint, i.e., consider thresholds that are in the middle between neighbouring datapoints (along that feature's dimension), not in the middle between any pair of datapoints.
#
# **Question 3 [10 credits]**. You guessed it, implement a node ```ContNode``` that selects a threshold value based on its training subset and classifies new datapoints based on whether they are smaller than that value, or not.

# %%
# This code must be modified.
#ANSQ3
def list_splits(input):
    value_l = sorted(input)
    
    split_l = [value_l[0] - 0.5*abs(value_[0])]
    for i, x in enumerate(value_l[:-1]):
        new_split = (x+value_l[i+1])/2
        if new_split not in split_l:
            split_l += [new_split]
    split_l += [value_l[-1] + 0.5*abs(value_[-1])]
    return split_l

class ContNode(Node):
    """Make a binary decision based on a threshold, for the value of the given feature"""
    def __init__(self, inputs, targets, feature):
        self.feature = feature
        self.IG      = 0.0
        self.H       = entropy(targets)                     # Entropy of unsplit data
        self.inputs  = inputs
        self.targets = targets

        N = float(targets.size)                             # Total number of datapoints

        for value in listValues(inputs[:,feature]):         # Go through all possible values for the given feature
            indicesTrue  = inputs[:,feature]==value         # Split the training data based on that feature/value
            indicesFalse = inputs[:,feature]!=value

            if indicesTrue.all() or indicesFalse.all():     # If none (or all) datapoints have the same value for that feature                  
                continue                                    # ... keep going

            children = [ Leaf(inputs[indicesTrue,:], targets[indicesTrue]),    # Temporarily create children
                         Leaf(inputs[indicesFalse,:], targets[indicesFalse]) ] # based on this split
            conditions = [ "%s==%s" % (fname[feature], value), "%s!=%s" % (fname[feature], value) ] # (for printing)

            Nt = float(children[0].targets.size)        # N.o. datapoints in True condition
            Nf = float(children[1].targets.size)        # N.o. datapoints in False condition
            pt = Nt/N
            pf = Nf/N
            ig = self.H - pt * children[0].entropy() - pf * children[1].entropy() # Compute the information gain 
                                                        # with the temporary children
            if ig > self.IG:                            # Check whether that information gain was better than what we had
                self.value = value                      # and if so, update the node and make those children permanent 
                self.IG = ig
                self.children = children
                self.conditions = conditions
        
        # Your code must fill in self.value here
        
    def entropy(self):
        return self.H
    
    def informationGain(self):
        """Return the entropy gain of splitting the given data according to 
        the specified feature and value"""
        return self.IG
    
    def classify(self, x):
        if x[self.feature] >= self.value:
            return self.children[0].classify(x)
        else:
            return self.children[1].classify(x)
        
    def __str__(self):
        return "=> threshold decision: %s >= %f" % (fname[self.feature],self.value)
#/ANSQ3

# %% [markdown]
# ## Classification based on mixed features
#
# The following dataset contains 14 features describing people's situation, and the classification task is to predict whether they earn more than \$50k a year or not. The categorical decision nodes we implemented above can work with any representation of categorical data, but the continuous decision node requires a numerical representation of the feature. Numpy arrays cannot easily contain both strings and numbers, and so to simplify our life, we converted the dataset to all numeric inputs and string targets.
#
# To allow our classifier to work with mixed features, we use a numerical representation of the categorical features in the following. So, let's first load the data:

# %%
# This code is given

income = np.load('income.npz')
print(income.keys())
inputs = income['inputs']
targets = income['targets']
fname = income['fnames']
ftypes = income['ftypes']

print(ftypes)
# Out:
# ['inputs', 'catindices', 'fnames', 'targets', 'ftypes']
# [b'continuous' b'categorical' b'continuous' b'categorical' b'continuous'
#  b'categorical' b'categorical' b'categorical' b'categorical'
#  b'categorical' b'continuous' b'continuous' b'continuous' b'categorical']

# %% [markdown]
# **Question 4 [10 credits]** Take 1000 training datapoints at random from the dataset, and another 1000 test points that are distinct from those (don't mix train and test). Train a decision tree on the train set and report the confusion matrix obtained on the test set. What are the obtained precision, recall and accuracy?

# %%
# Answer to Q4
#ANSQ4

#/ANSQ4
# Out:
# +->   => Binary decision: 'b'marital-status' =?= 1.0'
#    +-> b'marital-status'==1.0  => Binary decision: 'b'capital-gain' =?= 0.0'
#    |  +-> b'capital-gain'==0.0  => Binary decision: 'b'occupation' =?= 1.0'
#    |  |  +-> b'occupation'==1.0  => Binary decision: 'b'education' =?= 3.0'
#    |  |  |  +-> b'education'==3.0 			=> b'>50K' [Leaf]
#    |  |  |  +-> b'education'!=3.0  => Binary decision: 'b'education' =?= 0.0'
#    |  |  |     +-> b'education'==0.0  => Binary decision: 'b'capital-loss' =?= 0.0'
#    |  |  |     |  +-> b'capital-loss'==0.0  => Binary decision: 'b'relationship' =?= 3.0'
#    |  |  |     |  |  +-> b'relationship'==3.0 			=> b'<=50K' [Leaf]
#    |  |  |     |  |  +-> b'relationship'!=3.0  => Binary decision: 'b'hours-per-week' =?= 70.0'
#    |  |  |     |  |     +-> b'hours-per-week'==70.0 			=> b'<=50K' [Leaf]
#    |  |  |     |  |     +-> b'hours-per-week'!=70.0  => Binary decision: 'b'hours-per-week' =?= 55.0'
#    |  |  |     |  |        +-> b'hours-per-week'==55.0 			=> b'>50K' [Leaf]
#    |  |  |     |  |        +-> b'hours-per-week'!=55.0  => Binary decision: 'b'hours-per-week' =?= 20.0'
#    |  |  |     |  |           +-> b'hours-per-week'==20.0 			=> b'<=50K' [Leaf]
#    |  |  |     |  |           +-> b'hours-per-week'!=20.0  => Binary decision: 'b'age' =?= 43.0'
#    |  |  |     |  |              +-> b'age'==43.0 			=> b'<=50K' [Leaf]
#    |  |  |     |  |              +-> b'age'!=43.0  => Binary decision: 'b'age' =?= 42.0'
#    |  |  |     |  |                 +-> b'age'==42.0 			=> b'>50K' [Leaf]
#    |  |  |     |  |                 +-> b'age'!=42.0  => Binary decision: 'b'age' =?= 48.0'
#    |  |  |     |  |                    +-> b'age'==48.0 			=> b'>50K' [Leaf]
#    |  |  |     |  |                    +-> b'age'!=48.0  => Binary decision: 'b'age' =?= 46.0'
#    |  |  |     |  |                       +-> b'age'==46.0 			=> b'>50K' [Leaf]
#    |  |  |     |  |                       +-> b'age'!=46.0  => Binary decision: 'b'hours-per-week' =?= 50.0'
#    |  |  |     |  |                          +-> b'hours-per-week'==50.0 			=> b'>50K' [Leaf]
#    |  |  |     |  |                          +-> b'hours-per-week'!=50.0  => Binary decision: 'b'age' =?= 33.0'
#    |  |  |     |  |                             +-> b'age'==33.0 			=> b'>50K' [Leaf]
#    |  |  |     |  |                             +-> b'age'!=33.0 			=> b'>50K' [Leaf]
#    |  |  |     |  +-> b'capital-loss'!=0.0 			=> b'>50K' [Leaf]
#    |  |  |     +-> b'education'!=0.0  => Binary decision: 'b'workclass' =?= 1.0'
#    |  |  |        +-> b'workclass'==1.0 			=> b'<=50K' [Leaf]
#    |  |  |        +-> b'workclass'!=1.0  => Binary decision: 'b'education' =?= 9.0'
#    |  |  |           +-> b'education'==9.0 			=> b'>50K' [Leaf]
#    |  |  |           +-> b'education'!=9.0  => Binary decision: 'b'education' =?= 6.0'
#    |  |  |              +-> b'education'==6.0 			=> b'>50K' [Leaf]
#    |  |  |              +-> b'education'!=6.0  => Binary decision: 'b'capital-loss' =?= 1887.0'
#    |  |  |                 +-> b'capital-loss'==1887.0 			=> b'>50K' [Leaf]
#    |  |  |                 +-> b'capital-loss'!=1887.0  => Binary decision: 'b'capital-loss' =?= 1672.0'
#    |  |  |                    +-> b'capital-loss'==1672.0 			=> b'<=50K' [Leaf]
#    |  |  |                    +-> b'capital-loss'!=1672.0  => Binary decision: 'b'age' =?= 23.0'
#    |  |  |                       +-> b'age'==23.0 			=> b'<=50K' [Leaf]
#    |  |  |                       +-> b'age'!=23.0  => Binary decision: 'b'age' =?= 25.0'
#    |  |  |                          +-> b'age'==25.0 			=> b'<=50K' [Leaf]
#    |  |  |                          +-> b'age'!=25.0  => Binary decision: 'b'age' =?= 26.0'
#    |  |  |                             +-> b'age'==26.0 			=> b'<=50K' [Leaf]
#    |  |  |                             +-> b'age'!=26.0  => Binary decision: 'b'hours-per-week' =?= 42.0'
#    |  |  |                                +-> b'hours-per-week'==42.0 			=> b'>50K' [Leaf]
#    |  |  |                                +-> b'hours-per-week'!=42.0  => Binary decision: 'b'workclass' =?= 3.0'
#    |  |  |                                   +-> b'workclass'==3.0 			=> b'>50K' [Leaf]
#    |  |  |                                   +-> b'workclass'!=3.0  => Binary decision: 'b'capital-loss' =?= 1902.0'
#    |  |  |                                      +-> b'capital-loss'==1902.0 			=> b'>50K' [Leaf]
#    |  |  |                                      +-> b'capital-loss'!=1902.0  => Binary decision: 'b'hours-per-week' =?= 48.0'
#    |  |  |                                         +-> b'hours-per-week'==48.0 			=> b'<=50K' [Leaf]
#    |  |  |                                         +-> b'hours-per-week'!=48.0  => Binary decision: 'b'age' =?= 62.0'
#    |  |  |                                            +-> b'age'==62.0 			=> b'<=50K' [Leaf]
#    |  |  |                                            +-> b'age'!=62.0  => Binary decision: 'b'hours-per-week' =?= 50.0'
#    |  |  |                                               +-> b'hours-per-week'==50.0 			=> b'>50K' [Leaf]
#    |  |  |                                               +-> b'hours-per-week'!=50.0  => Binary decision: 'b'age' =?= 35.0'
#    |  |  |                                                  +-> b'age'==35.0 			=> b'<=50K' [Leaf]
#    |  |  |                                                  +-> b'age'!=35.0  => Binary decision: 'b'age' =?= 61.0'
#    |  |  |                                                     +-> b'age'==61.0 			=> b'>50K' [Leaf]
#    |  |  |                                                     +-> b'age'!=61.0  => Binary decision: 'b'age' =?= 31.0'
#    |  |  |                                                        +-> b'age'==31.0 			=> b'<=50K' [Leaf]
#    |  |  |                                                        +-> b'age'!=31.0  => Binary decision: 'b'hours-per-week' =?= 35.0'
#    |  |  |                                                           +-> b'hours-per-week'==35.0 			=> b'>50K' [Leaf]
#    |  |  |                                                           +-> b'hours-per-week'!=35.0  => Binary decision: 'b'race' =?= 1.0'
#    |  |  |                                                              +-> b'race'==1.0 			=> b'>50K' [Leaf]
#    |  |  |                                                              +-> b'race'!=1.0  => Binary decision: 'b'workclass' =?= 4.0'
#    |  |  |                                                                 +-> b'workclass'==4.0 			=> b'<=50K' [Leaf]
#    |  |  |                                                                 +-> b'workclass'!=4.0  => Binary decision: 'b'age' =?= 46.0'
#    |  |  |                                                                    +-> b'age'==46.0 			=> b'>50K' [Leaf]
#    |  |  |                                                                    +-> b'age'!=46.0  => Binary decision: 'b'age' =?= 44.0'
#    |  |  |                                                                       +-> b'age'==44.0 			=> b'<=50K' [Leaf]
#    |  |  |                                                                       +-> b'age'!=44.0  => Binary decision: 'b'hours-per-week' =?= 38.0'
#    |  |  |                                                                          +-> b'hours-per-week'==38.0 			=> b'<=50K' [Leaf]
#    |  |  |                                                                          +-> b'hours-per-week'!=38.0  => Binary decision: 'b'hours-per-week' =?= 16.0'
#    |  |  |                                                                             +-> b'hours-per-week'==16.0 			=> b'<=50K' [Leaf]
#    |  |  |                                                                             +-> b'hours-per-week'!=16.0  => Binary decision: 'b'hours-per-week' =?= 40.0'
#    |  |  |                                                                                +-> b'hours-per-week'==40.0 			=> b'<=50K' [Leaf]
#    |  |  |                                                                                +-> b'hours-per-week'!=40.0 			=> b'>50K' [Leaf]
#    |  |  +-> b'occupation'!=1.0  => Binary decision: 'b'occupation' =?= 3.0'
#    |  |     +-> b'occupation'==3.0  => Binary decision: 'b'capital-loss' =?= 1977.0'
#    |  |     |  +-> b'capital-loss'==1977.0 			=> b'>50K' [Leaf]
#    |  |     |  +-> b'capital-loss'!=1977.0  => Binary decision: 'b'education' =?= 9.0'
#    |  |     |     +-> b'education'==9.0 			=> b'>50K' [Leaf]
#    |  |     |     +-> b'education'!=9.0  => Binary decision: 'b'education' =?= 5.0'
#    |  |     |        +-> b'education'==5.0 			=> b'<=50K' [Leaf]
#    |  |     |        +-> b'education'!=5.0  => Binary decision: 'b'race' =?= 0.0'
#    |  |     |           +-> b'race'==0.0  => Binary decision: 'b'age' =?= 39.0'
#    |  |     |           |  +-> b'age'==39.0 			=> b'>50K' [Leaf]
#    |  |     |           |  +-> b'age'!=39.0  => Binary decision: 'b'hours-per-week' =?= 65.0'
#    |  |     |           |     +-> b'hours-per-week'==65.0 			=> b'<=50K' [Leaf]
#    |  |     |           |     +-> b'hours-per-week'!=65.0  => Binary decision: 'b'capital-loss' =?= 1902.0'
#    |  |     |           |        +-> b'capital-loss'==1902.0 			=> b'>50K' [Leaf]
#    |  |     |           |        +-> b'capital-loss'!=1902.0  => Binary decision: 'b'education' =?= 7.0'
#    |  |     |           |           +-> b'education'==7.0 			=> b'<=50K' [Leaf]
#    |  |     |           |           +-> b'education'!=7.0  => Binary decision: 'b'capital-loss' =?= 1887.0'
#    |  |     |           |              +-> b'capital-loss'==1887.0 			=> b'>50K' [Leaf]
#    |  |     |           |              +-> b'capital-loss'!=1887.0  => Binary decision: 'b'age' =?= 26.0'
#    |  |     |           |                 +-> b'age'==26.0 			=> b'<=50K' [Leaf]
#    |  |     |           |                 +-> b'age'!=26.0  => Binary decision: 'b'workclass' =?= 3.0'
#    |  |     |           |                    +-> b'workclass'==3.0 			=> b'>50K' [Leaf]
#    |  |     |           |                    +-> b'workclass'!=3.0  => Binary decision: 'b'education' =?= 10.0'
#    |  |     |           |                       +-> b'education'==10.0 			=> b'>50K' [Leaf]
#    |  |     |           |                       +-> b'education'!=10.0  => Binary decision: 'b'age' =?= 23.0'
#    |  |     |           |                          +-> b'age'==23.0 			=> b'<=50K' [Leaf]
#    |  |     |           |                          +-> b'age'!=23.0  => Binary decision: 'b'capital-loss' =?= 1740.0'
#    |  |     |           |                             +-> b'capital-loss'==1740.0 			=> b'<=50K' [Leaf]
#    |  |     |           |                             +-> b'capital-loss'!=1740.0  => Binary decision: 'b'relationship' =?= 2.0'
#    |  |     |           |                                +-> b'relationship'==2.0 			=> b'>50K' [Leaf]
#    |  |     |           |                                +-> b'relationship'!=2.0  => Binary decision: 'b'age' =?= 62.0'
#    |  |     |           |                                   +-> b'age'==62.0 			=> b'>50K' [Leaf]
#    |  |     |           |                                   +-> b'age'!=62.0  => Binary decision: 'b'age' =?= 45.0'
#    |  |     |           |                                      +-> b'age'==45.0 			=> b'>50K' [Leaf]
#    |  |     |           |                                      +-> b'age'!=45.0  => Binary decision: 'b'age' =?= 34.0'
#    |  |     |           |                                         +-> b'age'==34.0 			=> b'>50K' [Leaf]
#    |  |     |           |                                         +-> b'age'!=34.0  => Binary decision: 'b'age' =?= 55.0'
#    |  |     |           |                                            +-> b'age'==55.0 			=> b'>50K' [Leaf]
#    |  |     |           |                                            +-> b'age'!=55.0  => Binary decision: 'b'age' =?= 31.0'
#    |  |     |           |                                               +-> b'age'==31.0 			=> b'<=50K' [Leaf]
#    |  |     |           |                                               +-> b'age'!=31.0  => Binary decision: 'b'hours-per-week' =?= 40.0'
#    |  |     |           |                                                  +-> b'hours-per-week'==40.0 			=> b'>50K' [Leaf]
#    |  |     |           |                                                  +-> b'hours-per-week'!=40.0  => Binary decision: 'b'workclass' =?= 1.0'
#    |  |     |           |                                                     +-> b'workclass'==1.0 			=> b'>50K' [Leaf]
#    |  |     |           |                                                     +-> b'workclass'!=1.0  => Binary decision: 'b'age' =?= 32.0'
#    |  |     |           |                                                        +-> b'age'==32.0 			=> b'<=50K' [Leaf]
#    |  |     |           |                                                        +-> b'age'!=32.0 			=> b'>50K' [Leaf]
#    |  |     |           +-> b'race'!=0.0 			=> b'<=50K' [Leaf]
#    |  |     +-> b'occupation'!=3.0  => Binary decision: 'b'education' =?= 0.0'
#    |  |        +-> b'education'==0.0  => Binary decision: 'b'capital-loss' =?= 0.0'
#    |  |        |  +-> b'capital-loss'==0.0  => Binary decision: 'b'race' =?= 0.0'
#    |  |        |  |  +-> b'race'==0.0  => Binary decision: 'b'hours-per-week' =?= 45.0'
#    |  |        |  |  |  +-> b'hours-per-week'==45.0 			=> b'>50K' [Leaf]
#    |  |        |  |  |  +-> b'hours-per-week'!=45.0  => Binary decision: 'b'occupation' =?= 5.0'
#    |  |        |  |  |     +-> b'occupation'==5.0 			=> b'>50K' [Leaf]
#    |  |        |  |  |     +-> b'occupation'!=5.0  => Binary decision: 'b'relationship' =?= 2.0'
#    |  |        |  |  |        +-> b'relationship'==2.0 			=> b'>50K' [Leaf]
#    |  |        |  |  |        +-> b'relationship'!=2.0  => Binary decision: 'b'occupation' =?= 4.0'
#    |  |        |  |  |           +-> b'occupation'==4.0 			=> b'<=50K' [Leaf]
#    |  |        |  |  |           +-> b'occupation'!=4.0  => Binary decision: 'b'workclass' =?= 1.0'
#    |  |        |  |  |              +-> b'workclass'==1.0 			=> b'<=50K' [Leaf]
#    |  |        |  |  |              +-> b'workclass'!=1.0  => Binary decision: 'b'age' =?= 27.0'
#    |  |        |  |  |                 +-> b'age'==27.0 			=> b'<=50K' [Leaf]
#    |  |        |  |  |                 +-> b'age'!=27.0  => Binary decision: 'b'hours-per-week' =?= 50.0'
#    |  |        |  |  |                    +-> b'hours-per-week'==50.0 			=> b'>50K' [Leaf]
#    |  |        |  |  |                    +-> b'hours-per-week'!=50.0 			=> b'<=50K' [Leaf]
#    |  |        |  |  +-> b'race'!=0.0 			=> b'<=50K' [Leaf]
#    |  |        |  +-> b'capital-loss'!=0.0 			=> b'>50K' [Leaf]
#    |  |        +-> b'education'!=0.0  => Binary decision: 'b'occupation' =?= 10.0'
#    |  |           +-> b'occupation'==10.0 			=> b'>50K' [Leaf]
#    |  |           +-> b'occupation'!=10.0  => Binary decision: 'b'capital-loss' =?= 1887.0'
#    |  |              +-> b'capital-loss'==1887.0 			=> b'>50K' [Leaf]
#    |  |              +-> b'capital-loss'!=1887.0  => Binary decision: 'b'occupation' =?= 5.0'
#    |  |                 +-> b'occupation'==5.0  => Binary decision: 'b'capital-loss' =?= 1902.0'
#    |  |                 |  +-> b'capital-loss'==1902.0 			=> b'>50K' [Leaf]
#    |  |                 |  +-> b'capital-loss'!=1902.0  => Binary decision: 'b'age' =?= 30.0'
#    |  |                 |     +-> b'age'==30.0 			=> b'<=50K' [Leaf]
#    |  |                 |     +-> b'age'!=30.0  => Binary decision: 'b'hours-per-week' =?= 30.0'
#    |  |                 |        +-> b'hours-per-week'==30.0 			=> b'<=50K' [Leaf]
#    |  |                 |        +-> b'hours-per-week'!=30.0  => Binary decision: 'b'workclass' =?= 6.0'
#    |  |                 |           +-> b'workclass'==6.0 			=> b'>50K' [Leaf]
#    |  |                 |           +-> b'workclass'!=6.0  => Binary decision: 'b'hours-per-week' =?= 35.0'
#    |  |                 |              +-> b'hours-per-week'==35.0 			=> b'<=50K' [Leaf]
#    |  |                 |              +-> b'hours-per-week'!=35.0  => Binary decision: 'b'capital-loss' =?= 1977.0'
#    |  |                 |                 +-> b'capital-loss'==1977.0 			=> b'>50K' [Leaf]
#    |  |                 |                 +-> b'capital-loss'!=1977.0  => Binary decision: 'b'education' =?= 12.0'
#    |  |                 |                    +-> b'education'==12.0 			=> b'<=50K' [Leaf]
#    |  |                 |                    +-> b'education'!=12.0  => Binary decision: 'b'capital-loss' =?= 0.0'
#    |  |                 |                       +-> b'capital-loss'==0.0  => Binary decision: 'b'age' =?= 41.0'
#    |  |                 |                       |  +-> b'age'==41.0 			=> b'<=50K' [Leaf]
#    |  |                 |                       |  +-> b'age'!=41.0  => Binary decision: 'b'age' =?= 61.0'
#    |  |                 |                       |     +-> b'age'==61.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |     +-> b'age'!=61.0  => Binary decision: 'b'hours-per-week' =?= 38.0'
#    |  |                 |                       |        +-> b'hours-per-week'==38.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |        +-> b'hours-per-week'!=38.0  => Binary decision: 'b'hours-per-week' =?= 65.0'
#    |  |                 |                       |           +-> b'hours-per-week'==65.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |           +-> b'hours-per-week'!=65.0  => Binary decision: 'b'hours-per-week' =?= 80.0'
#    |  |                 |                       |              +-> b'hours-per-week'==80.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |              +-> b'hours-per-week'!=80.0  => Binary decision: 'b'age' =?= 66.0'
#    |  |                 |                       |                 +-> b'age'==66.0 			=> b'<=50K' [Leaf]
#    |  |                 |                       |                 +-> b'age'!=66.0  => Binary decision: 'b'age' =?= 69.0'
#    |  |                 |                       |                    +-> b'age'==69.0 			=> b'<=50K' [Leaf]
#    |  |                 |                       |                    +-> b'age'!=69.0  => Binary decision: 'b'hours-per-week' =?= 15.0'
#    |  |                 |                       |                       +-> b'hours-per-week'==15.0 			=> b'<=50K' [Leaf]
#    |  |                 |                       |                       +-> b'hours-per-week'!=15.0  => Binary decision: 'b'age' =?= 57.0'
#    |  |                 |                       |                          +-> b'age'==57.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                          +-> b'age'!=57.0  => Binary decision: 'b'hours-per-week' =?= 36.0'
#    |  |                 |                       |                             +-> b'hours-per-week'==36.0 			=> b'<=50K' [Leaf]
#    |  |                 |                       |                             +-> b'hours-per-week'!=36.0  => Binary decision: 'b'age' =?= 39.0'
#    |  |                 |                       |                                +-> b'age'==39.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                +-> b'age'!=39.0  => Binary decision: 'b'native-country' =?= 4.0'
#    |  |                 |                       |                                   +-> b'native-country'==4.0 			=> b'<=50K' [Leaf]
#    |  |                 |                       |                                   +-> b'native-country'!=4.0  => Binary decision: 'b'age' =?= 46.0'
#    |  |                 |                       |                                      +-> b'age'==46.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                      +-> b'age'!=46.0  => Binary decision: 'b'age' =?= 37.0'
#    |  |                 |                       |                                         +-> b'age'==37.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                         +-> b'age'!=37.0  => Binary decision: 'b'education' =?= 7.0'
#    |  |                 |                       |                                            +-> b'education'==7.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                            +-> b'education'!=7.0  => Binary decision: 'b'age' =?= 40.0'
#    |  |                 |                       |                                               +-> b'age'==40.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                               +-> b'age'!=40.0  => Binary decision: 'b'hours-per-week' =?= 55.0'
#    |  |                 |                       |                                                  +-> b'hours-per-week'==55.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                  +-> b'hours-per-week'!=55.0  => Binary decision: 'b'age' =?= 49.0'
#    |  |                 |                       |                                                     +-> b'age'==49.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                     +-> b'age'!=49.0  => Binary decision: 'b'education' =?= 3.0'
#    |  |                 |                       |                                                        +-> b'education'==3.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                        +-> b'education'!=3.0  => Binary decision: 'b'age' =?= 35.0'
#    |  |                 |                       |                                                           +-> b'age'==35.0 			=> b'<=50K' [Leaf]
#    |  |                 |                       |                                                           +-> b'age'!=35.0  => Binary decision: 'b'age' =?= 63.0'
#    |  |                 |                       |                                                              +-> b'age'==63.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                              +-> b'age'!=63.0  => Binary decision: 'b'age' =?= 67.0'
#    |  |                 |                       |                                                                 +-> b'age'==67.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                 +-> b'age'!=67.0  => Binary decision: 'b'fnlwgt' =?= 67072.0'
#    |  |                 |                       |                                                                    +-> b'fnlwgt'==67072.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                    +-> b'fnlwgt'!=67072.0  => Binary decision: 'b'fnlwgt' =?= 172034.0'
#    |  |                 |                       |                                                                       +-> b'fnlwgt'==172034.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                       +-> b'fnlwgt'!=172034.0  => Binary decision: 'b'fnlwgt' =?= 201732.0'
#    |  |                 |                       |                                                                          +-> b'fnlwgt'==201732.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                          +-> b'fnlwgt'!=201732.0  => Binary decision: 'b'fnlwgt' =?= 153614.0'
#    |  |                 |                       |                                                                             +-> b'fnlwgt'==153614.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                             +-> b'fnlwgt'!=153614.0  => Binary decision: 'b'age' =?= 34.0'
#    |  |                 |                       |                                                                                +-> b'age'==34.0 			=> b'<=50K' [Leaf]
#    |  |                 |                       |                                                                                +-> b'age'!=34.0  => Binary decision: 'b'fnlwgt' =?= 361494.0'
#    |  |                 |                       |                                                                                   +-> b'fnlwgt'==361494.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                   +-> b'fnlwgt'!=361494.0  => Binary decision: 'b'fnlwgt' =?= 103459.0'
#    |  |                 |                       |                                                                                      +-> b'fnlwgt'==103459.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                      +-> b'fnlwgt'!=103459.0  => Binary decision: 'b'fnlwgt' =?= 129573.0'
#    |  |                 |                       |                                                                                         +-> b'fnlwgt'==129573.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                         +-> b'fnlwgt'!=129573.0  => Binary decision: 'b'fnlwgt' =?= 35910.0'
#    |  |                 |                       |                                                                                            +-> b'fnlwgt'==35910.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                            +-> b'fnlwgt'!=35910.0  => Binary decision: 'b'fnlwgt' =?= 158315.0'
#    |  |                 |                       |                                                                                               +-> b'fnlwgt'==158315.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                               +-> b'fnlwgt'!=158315.0  => Binary decision: 'b'fnlwgt' =?= 126060.0'
#    |  |                 |                       |                                                                                                  +-> b'fnlwgt'==126060.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                                  +-> b'fnlwgt'!=126060.0  => Binary decision: 'b'fnlwgt' =?= 206964.0'
#    |  |                 |                       |                                                                                                     +-> b'fnlwgt'==206964.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                                     +-> b'fnlwgt'!=206964.0  => Binary decision: 'b'fnlwgt' =?= 81534.0'
#    |  |                 |                       |                                                                                                        +-> b'fnlwgt'==81534.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                                        +-> b'fnlwgt'!=81534.0  => Binary decision: 'b'fnlwgt' =?= 123011.0'
#    |  |                 |                       |                                                                                                           +-> b'fnlwgt'==123011.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                                           +-> b'fnlwgt'!=123011.0  => Binary decision: 'b'fnlwgt' =?= 67716.0'
#    |  |                 |                       |                                                                                                              +-> b'fnlwgt'==67716.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                                              +-> b'fnlwgt'!=67716.0  => Binary decision: 'b'fnlwgt' =?= 389254.0'
#    |  |                 |                       |                                                                                                                 +-> b'fnlwgt'==389254.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                                                 +-> b'fnlwgt'!=389254.0  => Binary decision: 'b'fnlwgt' =?= 266912.0'
#    |  |                 |                       |                                                                                                                    +-> b'fnlwgt'==266912.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                                                    +-> b'fnlwgt'!=266912.0  => Binary decision: 'b'fnlwgt' =?= 187046.0'
#    |  |                 |                       |                                                                                                                       +-> b'fnlwgt'==187046.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                                                       +-> b'fnlwgt'!=187046.0  => Binary decision: 'b'fnlwgt' =?= 149726.0'
#    |  |                 |                       |                                                                                                                          +-> b'fnlwgt'==149726.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                                                          +-> b'fnlwgt'!=149726.0  => Binary decision: 'b'fnlwgt' =?= 235237.0'
#    |  |                 |                       |                                                                                                                             +-> b'fnlwgt'==235237.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                                                             +-> b'fnlwgt'!=235237.0  => Binary decision: 'b'fnlwgt' =?= 233194.0'
#    |  |                 |                       |                                                                                                                                +-> b'fnlwgt'==233194.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                                                                +-> b'fnlwgt'!=233194.0  => Binary decision: 'b'fnlwgt' =?= 127215.0'
#    |  |                 |                       |                                                                                                                                   +-> b'fnlwgt'==127215.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                                                                   +-> b'fnlwgt'!=127215.0  => Binary decision: 'b'fnlwgt' =?= 197871.0'
#    |  |                 |                       |                                                                                                                                      +-> b'fnlwgt'==197871.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                                                                      +-> b'fnlwgt'!=197871.0  => Binary decision: 'b'fnlwgt' =?= 33521.0'
#    |  |                 |                       |                                                                                                                                         +-> b'fnlwgt'==33521.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                                                                         +-> b'fnlwgt'!=33521.0  => Binary decision: 'b'fnlwgt' =?= 123681.0'
#    |  |                 |                       |                                                                                                                                            +-> b'fnlwgt'==123681.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                                                                            +-> b'fnlwgt'!=123681.0  => Binary decision: 'b'fnlwgt' =?= 314153.0'
#    |  |                 |                       |                                                                                                                                               +-> b'fnlwgt'==314153.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                                                                               +-> b'fnlwgt'!=314153.0  => Binary decision: 'b'fnlwgt' =?= 58683.0'
#    |  |                 |                       |                                                                                                                                                  +-> b'fnlwgt'==58683.0 			=> b'>50K' [Leaf]
#    |  |                 |                       |                                                                                                                                                  +-> b'fnlwgt'!=58683.0  => Binary decision: 'b'hours-per-week' =?= 50.0'
#    |  |                 |                       |                                                                                                                                                     +-> b'hours-per-week'==50.0 			=> b'<=50K' [Leaf]
#    |  |                 |                       |                                                                                                                                                     +-> b'hours-per-week'!=50.0 			=> b'<=50K' [Leaf]
#    |  |                 |                       +-> b'capital-loss'!=0.0 			=> b'<=50K' [Leaf]
#    |  |                 +-> b'occupation'!=5.0  => Binary decision: 'b'education' =?= 2.0'
#    |  |                    +-> b'education'==2.0 			=> b'<=50K' [Leaf]
#    |  |                    +-> b'education'!=2.0  => Binary decision: 'b'capital-loss' =?= 1902.0'
#    |  |                       +-> b'capital-loss'==1902.0 			=> b'>50K' [Leaf]
#    |  |                       +-> b'capital-loss'!=1902.0  => Binary decision: 'b'capital-loss' =?= 1848.0'
#    |  |                          +-> b'capital-loss'==1848.0 			=> b'>50K' [Leaf]
#    |  |                          +-> b'capital-loss'!=1848.0  => Binary decision: 'b'occupation' =?= 8.0'
#    |  |                             +-> b'occupation'==8.0  => Binary decision: 'b'education' =?= 3.0'
#    |  |                             |  +-> b'education'==3.0 			=> b'>50K' [Leaf]
#    |  |                             |  +-> b'education'!=3.0  => Binary decision: 'b'fnlwgt' =?= 176186.0'
#    |  |                             |     +-> b'fnlwgt'==176186.0 			=> b'>50K' [Leaf]
#    |  |                             |     +-> b'fnlwgt'!=176186.0  => Binary decision: 'b'fnlwgt' =?= 184425.0'
#    |  |                             |        +-> b'fnlwgt'==184425.0 			=> b'>50K' [Leaf]
#    |  |                             |        +-> b'fnlwgt'!=184425.0  => Binary decision: 'b'fnlwgt' =?= 120460.0'
#    |  |                             |           +-> b'fnlwgt'==120460.0 			=> b'>50K' [Leaf]
#    |  |                             |           +-> b'fnlwgt'!=120460.0  => Binary decision: 'b'fnlwgt' =?= 177307.0'
#    |  |                             |              +-> b'fnlwgt'==177307.0 			=> b'>50K' [Leaf]
#    |  |                             |              +-> b'fnlwgt'!=177307.0  => Binary decision: 'b'fnlwgt' =?= 34987.0'
#    |  |                             |                 +-> b'fnlwgt'==34987.0 			=> b'>50K' [Leaf]
#    |  |                             |                 +-> b'fnlwgt'!=34987.0  => Binary decision: 'b'fnlwgt' =?= 113324.0'
#    |  |                             |                    +-> b'fnlwgt'==113324.0 			=> b'>50K' [Leaf]
#    |  |                             |                    +-> b'fnlwgt'!=113324.0  => Binary decision: 'b'fnlwgt' =?= 56026.0'
#    |  |                             |                       +-> b'fnlwgt'==56026.0 			=> b'>50K' [Leaf]
#    |  |                             |                       +-> b'fnlwgt'!=56026.0  => Binary decision: 'b'fnlwgt' =?= 134890.0'
#    |  |                             |                          +-> b'fnlwgt'==134890.0 			=> b'>50K' [Leaf]
#    |  |                             |                          +-> b'fnlwgt'!=134890.0  => Binary decision: 'b'fnlwgt' =?= 32537.0'
#    |  |                             |                             +-> b'fnlwgt'==32537.0 			=> b'>50K' [Leaf]
#    |  |                             |                             +-> b'fnlwgt'!=32537.0  => Binary decision: 'b'fnlwgt' =?= 195462.0'
#    |  |                             |                                +-> b'fnlwgt'==195462.0 			=> b'>50K' [Leaf]
#    |  |                             |                                +-> b'fnlwgt'!=195462.0  => Binary decision: 'b'fnlwgt' =?= 303044.0'
#    |  |                             |                                   +-> b'fnlwgt'==303044.0 			=> b'>50K' [Leaf]
#    |  |                             |                                   +-> b'fnlwgt'!=303044.0 			=> b'<=50K' [Leaf]
#    |  |                             +-> b'occupation'!=8.0  => Binary decision: 'b'capital-loss' =?= 1485.0'
#    |  |                                +-> b'capital-loss'==1485.0 			=> b'>50K' [Leaf]
#    |  |                                +-> b'capital-loss'!=1485.0  => Binary decision: 'b'workclass' =?= 3.0'
#    |  |                                   +-> b'workclass'==3.0 			=> b'>50K' [Leaf]
#    |  |                                   +-> b'workclass'!=3.0  => Binary decision: 'b'education' =?= 4.0'
#    |  |                                      +-> b'education'==4.0 			=> b'<=50K' [Leaf]
#    |  |                                      +-> b'education'!=4.0  => Binary decision: 'b'age' =?= 23.0'
#    |  |                                         +-> b'age'==23.0 			=> b'<=50K' [Leaf]
#    |  |                                         +-> b'age'!=23.0  => Binary decision: 'b'age' =?= 28.0'
#    |  |                                            +-> b'age'==28.0 			=> b'<=50K' [Leaf]
#    |  |                                            +-> b'age'!=28.0  => Binary decision: 'b'occupation' =?= 4.0'
#    |  |                                               +-> b'occupation'==4.0  => Binary decision: 'b'age' =?= 44.0'
#    |  |                                               |  +-> b'age'==44.0 			=> b'>50K' [Leaf]
#    |  |                                               |  +-> b'age'!=44.0  => Binary decision: 'b'race' =?= 0.0'
#    |  |                                               |     +-> b'race'==0.0  => Binary decision: 'b'workclass' =?= 6.0'
#    |  |                                               |     |  +-> b'workclass'==6.0 			=> b'>50K' [Leaf]
#    |  |                                               |     |  +-> b'workclass'!=6.0  => Binary decision: 'b'workclass' =?= 2.0'
#    |  |                                               |     |     +-> b'workclass'==2.0 			=> b'<=50K' [Leaf]
#    |  |                                               |     |     +-> b'workclass'!=2.0 			=> b'<=50K' [Leaf]
#    |  |                                               |     +-> b'race'!=0.0 			=> b'<=50K' [Leaf]
#    |  |                                               +-> b'occupation'!=4.0  => Binary decision: 'b'education' =?= 8.0'
#    |  |                                                  +-> b'education'==8.0 			=> b'<=50K' [Leaf]
#    |  |                                                  +-> b'education'!=8.0  => Binary decision: 'b'native-country' =?= 5.0'
#    |  |                                                     +-> b'native-country'==5.0 			=> b'<=50K' [Leaf]
#    |  |                                                     +-> b'native-country'!=5.0  => Binary decision: 'b'age' =?= 24.0'
#    |  |                                                        +-> b'age'==24.0 			=> b'<=50K' [Leaf]
#    |  |                                                        +-> b'age'!=24.0  => Binary decision: 'b'hours-per-week' =?= 80.0'
#    |  |                                                           +-> b'hours-per-week'==80.0 			=> b'>50K' [Leaf]
#    |  |                                                           +-> b'hours-per-week'!=80.0  => Binary decision: 'b'age' =?= 25.0'
#    |  |                                                              +-> b'age'==25.0 			=> b'<=50K' [Leaf]
#    |  |                                                              +-> b'age'!=25.0  => Binary decision: 'b'education' =?= 6.0'
#    |  |                                                                 +-> b'education'==6.0 			=> b'<=50K' [Leaf]
#    |  |                                                                 +-> b'education'!=6.0  => Binary decision: 'b'capital-loss' =?= 1977.0'
#    |  |                                                                    +-> b'capital-loss'==1977.0 			=> b'>50K' [Leaf]
#    |  |                                                                    +-> b'capital-loss'!=1977.0  => Binary decision: 'b'hours-per-week' =?= 25.0'
#    |  |                                                                       +-> b'hours-per-week'==25.0 			=> b'<=50K' [Leaf]
#    |  |                                                                       +-> b'hours-per-week'!=25.0  => Binary decision: 'b'education' =?= 12.0'
#    |  |                                                                          +-> b'education'==12.0 			=> b'<=50K' [Leaf]
#    |  |                                                                          +-> b'education'!=12.0  => Binary decision: 'b'hours-per-week' =?= 16.0'
#    |  |                                                                             +-> b'hours-per-week'==16.0 			=> b'<=50K' [Leaf]
#    |  |                                                                             +-> b'hours-per-week'!=16.0  => Binary decision: 'b'occupation' =?= 12.0'
#    |  |                                                                                +-> b'occupation'==12.0 			=> b'<=50K' [Leaf]
#    |  |                                                                                +-> b'occupation'!=12.0  => Binary decision: 'b'education' =?= 9.0'
#    |  |                                                                                   +-> b'education'==9.0 			=> b'>50K' [Leaf]
#    |  |                                                                                   +-> b'education'!=9.0  => Binary decision: 'b'capital-loss' =?= 0.0'
#    |  |                                                                                      +-> b'capital-loss'==0.0  => Binary decision: 'b'age' =?= 66.0'
#    |  |                                                                                      |  +-> b'age'==66.0 			=> b'<=50K' [Leaf]
#    |  |                                                                                      |  +-> b'age'!=66.0  => Binary decision: 'b'age' =?= 29.0'
#    |  |                                                                                      |     +-> b'age'==29.0 			=> b'<=50K' [Leaf]
#    |  |                                                                                      |     +-> b'age'!=29.0  => Binary decision: 'b'occupation' =?= 6.0'
#    |  |                                                                                      |        +-> b'occupation'==6.0  => Binary decision: 'b'age' =?= 30.0'
#    |  |                                                                                      |        |  +-> b'age'==30.0 			=> b'<=50K' [Leaf]
#    |  |                                                                                      |        |  +-> b'age'!=30.0  => Binary decision: 'b'workclass' =?= 4.0'
#    |  |                                                                                      |        |     +-> b'workclass'==4.0 			=> b'>50K' [Leaf]
#    |  |                                                                                      |        |     +-> b'workclass'!=4.0  => Binary decision: 'b'hours-per-week' =?= 55.0'
#    |  |                                                                                      |        |        +-> b'hours-per-week'==55.0 			=> b'>50K' [Leaf]
#    |  |                                                                                      |        |        +-> b'hours-per-week'!=55.0  => Binary decision: 'b'hours-per-week' =?= 20.0'
#    |  |                                                                                      |        |           +-> b'hours-per-week'==20.0 			=> b'<=50K' [Leaf]
#    |  |                                                                                      |        |           +-> b'hours-per-week'!=20.0  => Binary decision: 'b'race' =?= 1.0'
#    |  |                                                                                      |        |              +-> b'race'==1.0 			=> b'>50K' [Leaf]
#    |  |                                                                                      |        |              +-> b'race'!=1.0  => Binary decision: 'b'hours-per-week' =?= 30.0'
#    |  |                                                                                      |        |                 +-> b'hours-per-week'==30.0 			=> b'<=50K' [Leaf]
#    |  |                                                                                      |        |                 +-> b'hours-per-week'!=30.0  => Binary decision: 'b'age' =?= 35.0'
#    |  |                                                                                      |        |                    +-> b'age'==35.0 			=> b'<=50K' [Leaf]
#    |  |                                                                                      |        |                    +-> b'age'!=35.0  => Binary decision: 'b'education' =?= 13.0'
#    |  |                                                                                      |        |                       +-> b'education'==13.0 			=> b'<=50K' [Leaf]
#    |  |                                                                                      |        |                       +-> b'education'!=13.0  => Binary decision: 'b'age' =?= 27.0'
#    |  |                                                                                      |        |                          +-> b'age'==27.0 			=> b'<=50K' [Leaf]
#    |  |                                                                                      |        |                          +-> b'age'!=27.0  => Binary decision: 'b'native-country' =?= 15.0'
#    |  |                                                                                      |        |                             +-> b'native-country'==15.0 			=> b'<=50K' [Leaf]
#    |  |                                                                                      |        |                             +-> b'native-country'!=15.0  => Binary decision: 'b'hours-per-week' =?= 50.0'
#    |  |                                                                                      |        |                                +-> b'hours-per-week'==50.0 			=> b'<=50K' [Leaf]
# ...
#       |           |              |     +-> b'fnlwgt'!=123011.0  => Binary decision: 'b'fnlwgt' =?= 125461.0'
#       |           |              |        +-> b'fnlwgt'==125461.0 			=> b'>50K' [Leaf]
#       |           |              |        +-> b'fnlwgt'!=125461.0  => Binary decision: 'b'fnlwgt' =?= 205339.0'
#       |           |              |           +-> b'fnlwgt'==205339.0 			=> b'>50K' [Leaf]
#       |           |              |           +-> b'fnlwgt'!=205339.0  => Binary decision: 'b'fnlwgt' =?= 258819.0'
#       |           |              |              +-> b'fnlwgt'==258819.0 			=> b'>50K' [Leaf]
#       |           |              |              +-> b'fnlwgt'!=258819.0  => Binary decision: 'b'fnlwgt' =?= 318280.0'
#       |           |              |                 +-> b'fnlwgt'==318280.0 			=> b'>50K' [Leaf]
#       |           |              |                 +-> b'fnlwgt'!=318280.0  => Binary decision: 'b'fnlwgt' =?= 119859.0'
#       |           |              |                    +-> b'fnlwgt'==119859.0 			=> b'>50K' [Leaf]
#       |           |              |                    +-> b'fnlwgt'!=119859.0  => Binary decision: 'b'fnlwgt' =?= 230624.0'
#       |           |              |                       +-> b'fnlwgt'==230624.0 			=> b'>50K' [Leaf]
#       |           |              |                       +-> b'fnlwgt'!=230624.0  => Binary decision: 'b'fnlwgt' =?= 228723.0'
#       |           |              |                          +-> b'fnlwgt'==228723.0 			=> b'>50K' [Leaf]
#       |           |              |                          +-> b'fnlwgt'!=228723.0  => Binary decision: 'b'fnlwgt' =?= 85604.0'
#       |           |              |                             +-> b'fnlwgt'==85604.0 			=> b'>50K' [Leaf]
#       |           |              |                             +-> b'fnlwgt'!=85604.0  => Binary decision: 'b'fnlwgt' =?= 282398.0'
#       |           |              |                                +-> b'fnlwgt'==282398.0 			=> b'>50K' [Leaf]
#       |           |              |                                +-> b'fnlwgt'!=282398.0  => Binary decision: 'b'fnlwgt' =?= 173924.0'
#       |           |              |                                   +-> b'fnlwgt'==173924.0 			=> b'>50K' [Leaf]
#       |           |              |                                   +-> b'fnlwgt'!=173924.0  => Binary decision: 'b'fnlwgt' =?= 247807.0'
#       |           |              |                                      +-> b'fnlwgt'==247807.0 			=> b'>50K' [Leaf]
#       |           |              |                                      +-> b'fnlwgt'!=247807.0 			=> b'<=50K' [Leaf]
#       |           |              +-> b'hours-per-week'!=40.0  => Binary decision: 'b'education' =?= 3.0'
#       |           |                 +-> b'education'==3.0 			=> b'<=50K' [Leaf]
#       |           |                 +-> b'education'!=3.0  => Binary decision: 'b'age' =?= 48.0'
#       |           |                    +-> b'age'==48.0 			=> b'>50K' [Leaf]
#       |           |                    +-> b'age'!=48.0  => Binary decision: 'b'capital-loss' =?= 2258.0'
#       |           |                       +-> b'capital-loss'==2258.0 			=> b'>50K' [Leaf]
#       |           |                       +-> b'capital-loss'!=2258.0  => Binary decision: 'b'age' =?= 71.0'
#       |           |                          +-> b'age'==71.0 			=> b'>50K' [Leaf]
#       |           |                          +-> b'age'!=71.0  => Binary decision: 'b'age' =?= 77.0'
#       |           |                             +-> b'age'==77.0 			=> b'>50K' [Leaf]
#       |           |                             +-> b'age'!=77.0  => Binary decision: 'b'fnlwgt' =?= 323605.0'
#       |           |                                +-> b'fnlwgt'==323605.0 			=> b'>50K' [Leaf]
#       |           |                                +-> b'fnlwgt'!=323605.0  => Binary decision: 'b'occupation' =?= 4.0'
#       |           |                                   +-> b'occupation'==4.0 			=> b'<=50K' [Leaf]
#       |           |                                   +-> b'occupation'!=4.0  => Binary decision: 'b'age' =?= 52.0'
#       |           |                                      +-> b'age'==52.0 			=> b'>50K' [Leaf]
#       |           |                                      +-> b'age'!=52.0  => Binary decision: 'b'age' =?= 57.0'
#       |           |                                         +-> b'age'==57.0 			=> b'>50K' [Leaf]
#       |           |                                         +-> b'age'!=57.0  => Binary decision: 'b'fnlwgt' =?= 96299.0'
#       |           |                                            +-> b'fnlwgt'==96299.0 			=> b'>50K' [Leaf]
#       |           |                                            +-> b'fnlwgt'!=96299.0  => Binary decision: 'b'fnlwgt' =?= 190525.0'
#       |           |                                               +-> b'fnlwgt'==190525.0 			=> b'>50K' [Leaf]
#       |           |                                               +-> b'fnlwgt'!=190525.0  => Binary decision: 'b'fnlwgt' =?= 163998.0'
#       |           |                                                  +-> b'fnlwgt'==163998.0 			=> b'>50K' [Leaf]
#       |           |                                                  +-> b'fnlwgt'!=163998.0  => Binary decision: 'b'fnlwgt' =?= 80058.0'
#       |           |                                                     +-> b'fnlwgt'==80058.0 			=> b'>50K' [Leaf]
#       |           |                                                     +-> b'fnlwgt'!=80058.0  => Binary decision: 'b'fnlwgt' =?= 92440.0'
#       |           |                                                        +-> b'fnlwgt'==92440.0 			=> b'>50K' [Leaf]
#       |           |                                                        +-> b'fnlwgt'!=92440.0  => Binary decision: 'b'fnlwgt' =?= 76107.0'
#       |           |                                                           +-> b'fnlwgt'==76107.0 			=> b'>50K' [Leaf]
#       |           |                                                           +-> b'fnlwgt'!=76107.0  => Binary decision: 'b'fnlwgt' =?= 70037.0'
#       |           |                                                              +-> b'fnlwgt'==70037.0 			=> b'>50K' [Leaf]
#       |           |                                                              +-> b'fnlwgt'!=70037.0  => Binary decision: 'b'fnlwgt' =?= 39352.0'
#       |           |                                                                 +-> b'fnlwgt'==39352.0 			=> b'>50K' [Leaf]
#       |           |                                                                 +-> b'fnlwgt'!=39352.0  => Binary decision: 'b'fnlwgt' =?= 350661.0'
#       |           |                                                                    +-> b'fnlwgt'==350661.0 			=> b'>50K' [Leaf]
#       |           |                                                                    +-> b'fnlwgt'!=350661.0  => Binary decision: 'b'fnlwgt' =?= 227890.0'
#       |           |                                                                       +-> b'fnlwgt'==227890.0 			=> b'>50K' [Leaf]
#       |           |                                                                       +-> b'fnlwgt'!=227890.0  => Binary decision: 'b'fnlwgt' =?= 180871.0'
#       |           |                                                                          +-> b'fnlwgt'==180871.0 			=> b'>50K' [Leaf]
#       |           |                                                                          +-> b'fnlwgt'!=180871.0  => Binary decision: 'b'fnlwgt' =?= 213722.0'
#       |           |                                                                             +-> b'fnlwgt'==213722.0 			=> b'>50K' [Leaf]
#       |           |                                                                             +-> b'fnlwgt'!=213722.0  => Binary decision: 'b'fnlwgt' =?= 152373.0'
#       |           |                                                                                +-> b'fnlwgt'==152373.0 			=> b'>50K' [Leaf]
#       |           |                                                                                +-> b'fnlwgt'!=152373.0  => Binary decision: 'b'fnlwgt' =?= 23438.0'
#       |           |                                                                                   +-> b'fnlwgt'==23438.0 			=> b'>50K' [Leaf]
#       |           |                                                                                   +-> b'fnlwgt'!=23438.0  => Binary decision: 'b'fnlwgt' =?= 363418.0'
#       |           |                                                                                      +-> b'fnlwgt'==363418.0 			=> b'>50K' [Leaf]
#       |           |                                                                                      +-> b'fnlwgt'!=363418.0  => Binary decision: 'b'fnlwgt' =?= 284166.0'
#       |           |                                                                                         +-> b'fnlwgt'==284166.0 			=> b'>50K' [Leaf]
#       |           |                                                                                         +-> b'fnlwgt'!=284166.0  => Binary decision: 'b'fnlwgt' =?= 30267.0'
#       |           |                                                                                            +-> b'fnlwgt'==30267.0 			=> b'>50K' [Leaf]
#       |           |                                                                                            +-> b'fnlwgt'!=30267.0  => Binary decision: 'b'fnlwgt' =?= 345705.0'
#       |           |                                                                                               +-> b'fnlwgt'==345705.0 			=> b'>50K' [Leaf]
#       |           |                                                                                               +-> b'fnlwgt'!=345705.0  => Binary decision: 'b'fnlwgt' =?= 147110.0'
#       |           |                                                                                                  +-> b'fnlwgt'==147110.0 			=> b'>50K' [Leaf]
#       |           |                                                                                                  +-> b'fnlwgt'!=147110.0  => Binary decision: 'b'fnlwgt' =?= 177905.0'
#       |           |                                                                                                     +-> b'fnlwgt'==177905.0 			=> b'>50K' [Leaf]
#       |           |                                                                                                     +-> b'fnlwgt'!=177905.0 			=> b'<=50K' [Leaf]
#       |           +-> b'sex'!=0.0  => Binary decision: 'b'education' =?= 0.0'
#       |              +-> b'education'==0.0  => Binary decision: 'b'occupation' =?= 0.0'
#       |              |  +-> b'occupation'==0.0 			=> b'<=50K' [Leaf]
#       |              |  +-> b'occupation'!=0.0 			=> b'<=50K' [Leaf]
#       |              +-> b'education'!=0.0  => Binary decision: 'b'marital-status' =?= 2.0'
#       |                 +-> b'marital-status'==2.0  => Binary decision: 'b'occupation' =?= 12.0'
#       |                 |  +-> b'occupation'==12.0 			=> b'<=50K' [Leaf]
#       |                 |  +-> b'occupation'!=12.0  => Binary decision: 'b'age' =?= 55.0'
#       |                 |     +-> b'age'==55.0 			=> b'<=50K' [Leaf]
#       |                 |     +-> b'age'!=55.0  => Binary decision: 'b'age' =?= 69.0'
#       |                 |        +-> b'age'==69.0 			=> b'>50K' [Leaf]
#       |                 |        +-> b'age'!=69.0  => Binary decision: 'b'fnlwgt' =?= 319560.0'
#       |                 |           +-> b'fnlwgt'==319560.0 			=> b'>50K' [Leaf]
#       |                 |           +-> b'fnlwgt'!=319560.0  => Binary decision: 'b'fnlwgt' =?= 119904.0'
#       |                 |              +-> b'fnlwgt'==119904.0 			=> b'>50K' [Leaf]
#       |                 |              +-> b'fnlwgt'!=119904.0  => Binary decision: 'b'fnlwgt' =?= 365683.0'
#       |                 |                 +-> b'fnlwgt'==365683.0 			=> b'>50K' [Leaf]
#       |                 |                 +-> b'fnlwgt'!=365683.0  => Binary decision: 'b'fnlwgt' =?= 179580.0'
#       |                 |                    +-> b'fnlwgt'==179580.0 			=> b'>50K' [Leaf]
#       |                 |                    +-> b'fnlwgt'!=179580.0  => Binary decision: 'b'fnlwgt' =?= 372181.0'
#       |                 |                       +-> b'fnlwgt'==372181.0 			=> b'>50K' [Leaf]
#       |                 |                       +-> b'fnlwgt'!=372181.0  => Binary decision: 'b'fnlwgt' =?= 124487.0'
#       |                 |                          +-> b'fnlwgt'==124487.0 			=> b'>50K' [Leaf]
#       |                 |                          +-> b'fnlwgt'!=124487.0  => Binary decision: 'b'fnlwgt' =?= 20296.0'
#       |                 |                             +-> b'fnlwgt'==20296.0 			=> b'>50K' [Leaf]
#       |                 |                             +-> b'fnlwgt'!=20296.0  => Binary decision: 'b'fnlwgt' =?= 65372.0'
#       |                 |                                +-> b'fnlwgt'==65372.0 			=> b'>50K' [Leaf]
#       |                 |                                +-> b'fnlwgt'!=65372.0 			=> b'<=50K' [Leaf]
#       |                 +-> b'marital-status'!=2.0  => Binary decision: 'b'fnlwgt' =?= 137618.0'
#       |                    +-> b'fnlwgt'==137618.0 			=> b'>50K' [Leaf]
#       |                    +-> b'fnlwgt'!=137618.0  => Binary decision: 'b'fnlwgt' =?= 168381.0'
#       |                       +-> b'fnlwgt'==168381.0 			=> b'>50K' [Leaf]
#       |                       +-> b'fnlwgt'!=168381.0  => Binary decision: 'b'fnlwgt' =?= 163113.0'
#       |                          +-> b'fnlwgt'==163113.0 			=> b'>50K' [Leaf]
#       |                          +-> b'fnlwgt'!=163113.0  => Binary decision: 'b'fnlwgt' =?= 132930.0'
#       |                             +-> b'fnlwgt'==132930.0 			=> b'>50K' [Leaf]
#       |                             +-> b'fnlwgt'!=132930.0 			=> b'<=50K' [Leaf]
#       +-> b'capital-gain'!=0.0  => Binary decision: 'b'capital-gain' =?= 8614.0'
#          +-> b'capital-gain'==8614.0 			=> b'>50K' [Leaf]
#          +-> b'capital-gain'!=8614.0  => Binary decision: 'b'capital-gain' =?= 10520.0'
#             +-> b'capital-gain'==10520.0 			=> b'>50K' [Leaf]
#             +-> b'capital-gain'!=10520.0  => Binary decision: 'b'capital-gain' =?= 14084.0'
#                +-> b'capital-gain'==14084.0 			=> b'>50K' [Leaf]
#                +-> b'capital-gain'!=14084.0  => Binary decision: 'b'capital-gain' =?= 27828.0'
#                   +-> b'capital-gain'==27828.0 			=> b'>50K' [Leaf]
#                   +-> b'capital-gain'!=27828.0  => Binary decision: 'b'capital-gain' =?= 14344.0'
#                      +-> b'capital-gain'==14344.0 			=> b'>50K' [Leaf]
#                      +-> b'capital-gain'!=14344.0  => Binary decision: 'b'capital-gain' =?= 99999.0'
#                         +-> b'capital-gain'==99999.0 			=> b'>50K' [Leaf]
#                         +-> b'capital-gain'!=99999.0  => Binary decision: 'b'capital-gain' =?= 13550.0'
#                            +-> b'capital-gain'==13550.0 			=> b'>50K' [Leaf]
#                            +-> b'capital-gain'!=13550.0  => Binary decision: 'b'relationship' =?= 4.0'
#                               +-> b'relationship'==4.0 			=> b'<=50K' [Leaf]
#                               +-> b'relationship'!=4.0  => Binary decision: 'b'capital-gain' =?= 4787.0'
#                                  +-> b'capital-gain'==4787.0 			=> b'>50K' [Leaf]
#                                  +-> b'capital-gain'!=4787.0  => Binary decision: 'b'age' =?= 74.0'
#                                     +-> b'age'==74.0 			=> b'>50K' [Leaf]
#                                     +-> b'age'!=74.0  => Binary decision: 'b'fnlwgt' =?= 111177.0'
#                                        +-> b'fnlwgt'==111177.0 			=> b'>50K' [Leaf]
#                                        +-> b'fnlwgt'!=111177.0  => Binary decision: 'b'fnlwgt' =?= 222810.0'
#                                           +-> b'fnlwgt'==222810.0 			=> b'>50K' [Leaf]
#                                           +-> b'fnlwgt'!=222810.0 			=> b'<=50K' [Leaf]
