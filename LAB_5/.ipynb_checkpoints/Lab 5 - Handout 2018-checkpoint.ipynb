# %% [markdown]
# <table>
#     <tr><td><b>Names</b></td><td>Thibault Douzon & Rajavarman Mathivanan</td></tr>
#     <tr><td><b>Group</b></td><td>BML36</td></tr>
# </table>

# %% [markdown]
# $
# \newcommand{\x}{\mathbf{x}}
# \newcommand{\w}{\mathbf{w}}
# \newcommand{\z}{\mathbf{z}}
# \newcommand{\wx}{\w^\top\x}
# \newcommand{\dataset}{\mathbf{X}}
# \newcommand{\tset}{t\negthickspace t}
# $
#
# # Week 5: Neural networks
#
# The basic unit of a multi-layer perceptron (MLP) is the neuron, which is a computational unit that computes a weighted sum of its inputs $\wx$ and pushes this through a non-linear activation function. Important is that this activation should be differentiable, as we will train the weights of the network by gradient descent. This requires that we should be able to compute the gradient of an error function with respect to the weights.
#
# In a sense, this whole lab is about taking derivatives and applying the chain rule of derivation. As a reminder, the rule is that the derivative of a function $f$ applied to the result of a function $g$ $f(g(x))$ can be decomposed as:
# $$
# \frac{\partial}{\partial x} f(g(x)) = \frac{\partial f(g(x))}{\partial g(x)} \, \frac{\partial g(x)}{\partial x}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import copy


def gradDesc(w, errorfn, gradfn,  eta=1e-3, verbose=True, maxit=100):
    """Find a minimum of a function using Gradient Descent
    
    Inputs:
        w: Initialisation of the weights
        errorfn: the function of w to minimise
        gradfn:  The gradient of that function w.r.t. w
        eta:     The initial value of the step size
        verbose: Whether to print out progress information
        
    Outputs:
        - The value of w at which the minimum is achieved
        - a list errors for the different iterations
        - a list of the corresponding time steps
    
    """
    err = errorfn(w)             # Compute the error function
    errs = np.zeros(maxit)       # Keep track of the error function
    ts = np.zeros(maxit)         # Keep track of time stamps
    start = time.time()

    newError = errorfn(w) + 1.
    for n in range(maxit):
        grad = gradfn(w)
        if verbose:
            print("##", n, "err:", newError, "eta:", eta, "w:", w)
            print("  Gradient:", grad)
            #print("  FD grad: ", gradfd(w,errorfn))
        pw = copy.copy(w)
        w -= grad * eta     # Update the weights
        
        pastError = newError
        newError = errorfn(w)
        while eta > 0. and pastError - newError < 0: # If the error increases, eta is too large
            eta /= 2.0                                # halve it, and
            w = pw - eta * grad                      # try again from the original value of the weights
            newError = errorfn(w)
        else:                                        # If the error goes down,
            eta *= 1.2                               # try to increase eta a little, to speed up things.
                
        if pastError-newError < 1e-5:                # If we couldn't decrease the error anymore, 
            return w, errs[:n], ts[:n]               # just give up
 
        errs[n] = newError                           # Keep track of how the errors evolved
        ts[n] = time.time()-start

    return w, errs, ts


def sigma(a):
    """Numerically stable implementation of the logistic function"""
    return 0. if a<-40. else 1. if a>40. else 1./(1.+np.exp(-a))
sigma = np.vectorize(sigma) # make sigma work elementwise on vectors too

def gradSigma(a):
    """Return the derivative of the logistic function w.r.t. its function parameter"""
    s = sigma(a)
    return s*(1.-s)

# %% [markdown]
# ## Neuron definition
#
# In this case, let's set up our network to have the sigmoidal activation function that we've seen before in logistic regression,
# $$
# \sigma(a) = \frac{1}{1+e^{-a}}\ ,
# $$
# so that the activation $z_i$ of neuron $i$ in the first computational layer is given by
# $$
# z_i = \sigma(\w_i^\top \x) \ ,
# $$
# where $\x$ is the input datapoint, and $\w_i$ is the set of input weights to neuron $i$. Other activation functions are possible, such as a linear function ($z=\wx$) or a hyperbolic tangent ($z=\tanh(\wx)$). Let's consider a network of a single neuron, then the output of our network $y(\w,\x) = \sigma(\wx)$.
#
# ## Training
#
# To train a single neuron, we have a set of datapoints $\dataset = \{ \x_1\dots \x_N\}$ and corresponding targets $\tset = \{ t_1 \dots t_N \}$. We use this dataset to find optimal weights, and we define optimality on terms of an error function. Let's define our error function as a sum of squared errors:
# $$
# E(\w) = \tfrac{1}{2} \sum_{n=1}^N (y(\w,\x_n) - t_n)^2
# $$
#
# Notice how, although our single neuron is very similar to the logistic regression we saw in previous weeks, our error function is now quite different. The error for our set $\dataset, \tset$ is now:
# $$
# E(\w) = \frac{1}{2}\sum_{n=1}^N (\sigma(\w^\top\x_n) - t_n)^2
# $$

# %% [markdown]
# **Question 1 [5 credits]** What is the partial derivative of this error with respect to the $i$th weight of the neuron, $w_i$? Be careful, this is not the same as what we saw in the lecture, where the output neuron had a linear activation function. Remember that $\w^\top\x \triangleq \sum_{i=0}^D w_i x_i$

# %% [markdown]
# ANSQ1
#
# $$
# \frac{\partial E}{\partial w_i}(w) = \frac{\partial \frac{1}{2}\sum_{n=1}^N (\sigma(w^\top x_n) - t_n)^2}{\partial w_i}
# $$
# $$
# \frac{\partial E}{\partial w_i}(w) =\sum_{n=1}^N \frac{\partial \frac{1}{2} (\sigma(w^\top x_n) - t_n)^2}{\partial \sigma(w^\top x_n)-t_n} \cdot \frac{\partial \sigma(w^\top x_n)-t_n}{\partial w^\top x_n}\cdot \frac{\partial w^\top x_n}{\partial w_i}
# $$
# $$
# \frac{\partial E}{\partial w_i}(w) =\sum_{n=1}^N (\sigma(w^\top x_n)-t_n) \cdot \sigma(w^\top x_n)(1-\sigma(w^\top x_n)) \cdot x_{n,i}
# $$
#
# /ANSQ1

# %% [markdown]
# **Question 2 [10 credits]** If now we had a neural network with two layers of one neuron each (one hidden and one output node), both with sigmoidal activation functions,
# * what would be the error function, analytically?
# * What is the derivative of that error with respect to the weights of the first and second layer?
#
# For ease of notation, let's assume there is no bias term in the second layer. The input is still a vector $
# \x$ with multiple dimensions, however.
#
# How do your equations correspond to the quantities computed in backpropagation?

# %% [markdown]
# ANSQ2
# $$
# \frac{\partial E}{\partial w_i}(w) = \frac{\partial \frac{1}{2}\sum_{n=1}^N (\sigma(w^\top x_n) - t_n)^2}{\partial w_i}
# $$
# $$
# \frac{\partial E}{\partial w_i}(w) =\sum_{n=1}^N \frac{\partial \frac{1}{2} (\sigma(w^\top x_n) - t_n)^2}{\partial \sigma(w^\top x_n)-t_n} \cdot \frac{\partial \sigma(w^\top x_n)-t_n}{\partial w^\top x_n}\cdot \frac{\partial w^\top x_n}{\partial w_i}
# $$
# $$
# \frac{\partial E}{\partial w_i}(w) =\sum_{n=1}^N (\sigma(w^\top x_n)-t_n) \cdot \sigma(w^\top x_n)(1-\sigma(w^\top x_n)) \cdot x_{n,i}
# $$
# $$
# \frac{A}{B} = \frac{A}{D}\times\frac{D}{C}\times\frac{C}{B}
# $$
# $$
# E(w) = \frac{1}{2}\sum_{n=1}^N (\sigma(w^{(1)}\cdot\sigma({w^{(0)}}^\top x_n)) - t_n)^2
# $$
# $$
# \frac{\partial E}{\partial w^{(1)}}(w) =  \frac{\partial \frac{1}{2}\sum_{n=1}^N(\sigma(w^{(1)}\cdot\sigma({{w^{(0)}}^\top x_n})) - t_n)^2}{\partial w^{(1)}}
# $$
# $$
# \frac{\partial E}{\partial w^{(1)}}(w) = \sum_{n=1}^N \frac{\partial\frac{1}{2}(\sigma(w^{(1)}\cdot\sigma({{w^{(0)}}^\top x_n})) - t_n)^2}{\partial \sigma(w^{(1)}\cdot\sigma({{w^{(0)}}^\top x_n})) - t_n} \cdot \frac{\partial\sigma(w^{(1)}\cdot\sigma({{w^{(0)}}^\top x_n})) - t_n}{w^{(1)}\cdot\sigma({{w^{(0)}}^\top x_n})}\cdot\frac{\partial w^{(1)}\cdot\sigma({{w^{(0)}}^\top x_n})}{\partial w^{(1)}}
# $$
# $$
# \frac{\partial E}{\partial w^{(1)}}(w) = \sum_{n=1}^N (\sigma(w^{(1)}\cdot\sigma({{w^{(0)}}^\top x_n}))-t_n)\cdot \sigma(w^{(1)}\cdot\sigma({{w^{(0)}}^\top x_n}))(1-\sigma(w^{(1)}\cdot\sigma({{w^{(0)}}^\top x_n})))\cdot \sigma({{w^{(0)}}^\top x_n})
# $$
# set
# $$
# a_0 = {{w^{(0)}}^\top x_n}\text{ and }a_1 = {{w^{(1)}}^\top \sigma(a_0)} \text{ and }\delta_1 = (\sigma(a_1)-t_n)\cdot \sigma(a_1)(1-\sigma(a_1))
# $$
# $$
# \frac{\partial E}{\partial w^{(1)}}(w) = \sum_{n=1}^N \delta_1\cdot  \sigma(a_0)
# $$
#
# $$
# \frac{\partial E}{\partial w^{(0)}_i}(w) = \frac{\partial \frac{1}{2}\sum_{n=1}^N(\sigma(w^{(1)}\cdot\sigma({{w^{(0)}}^\top x_n})) - t_n)^2}{\partial w^{(0)}_i}
# $$
# $$
# \frac{\partial E}{\partial w^{(0)}_i}(w) = \sum_{n=1}^N \frac{\partial\frac{1}{2}(\sigma(w^{(1)}\cdot\sigma({{w^{(0)}}^\top x_n})) - t_n)^2}{\partial \sigma(w^{(1)}\cdot\sigma({{w^{(0)}}^\top x_n})) - t_n} \cdot \frac{\partial\sigma(w^{(1)}\cdot\sigma({{w^{(0)}}^\top x_n})) - t_n}{w^{(1)}\cdot\sigma({{w^{(0)}}^\top x_n})}\cdot\frac{\partial w^{(1)}\cdot\sigma({{w^{(0)}}^\top x_n})}{\partial {w^{(0)}}^\top x_n}\cdot \frac{\partial {w^{(0)}}^\top x_n}{\partial w^{(0)}_i}
# $$
# $$
# \frac{\partial E}{\partial w^{(0)}_i}(w) = \sum_{n=1}^N (\sigma(w^{(1)}\cdot\sigma({{w^{(0)}}^\top x_n}))-t_n)\cdot \sigma(w^{(1)}\cdot\sigma({{w^{(0)}}^\top x_n}))(1-\sigma(w^{(1)}\cdot\sigma({{w^{(0)}}^\top x_n})))\cdot w^{(1)}\sigma({{w^{(0)}}^\top x_n})(1-\sigma({{w^{(0)}}^\top x_n}))\cdot x_{n,i}
# $$
# $$
# \frac{\partial e}{\partial w^{(0)}_i}(w) = \sum_{n=1}^n \delta_1\cdot w^{(1)}\sigma(a_0)(1-\sigma(a_0))\cdot x_{n,i}
# $$
# set
# $$
# \delta_0 = \delta_1\cdot w^{(1)}\sigma(a_0)(1-\sigma(a_0))
# $$
# $$
# \frac{\partial E}{\partial w^{(0)}_i}(w) = \delta_0 x_{n,i}
# $$
# /ANSQ2

# %% [markdown]
# **Question 3 [10 credits]** Implement the following python functions:
#
# * `sse(output, target)`, which implements the squared error between the given network output and the corresponding target. Both are assumed to be scalars, not vectors.
# * `gradSse(output,target)`, which computes the gradient of that error with respect to its input variable `output`
# * `neuron(weights, inputs)`, wich implements a neuron with sigmoidal activation function, weights $\w$ and inputs $\x$. Assume that this function will receive an augmented vector $\x$, where the first element is fixed to $1$, so you do not need to handle the bias parameter separately
# * `gradNeuron(weights, inputs)`, which implements the gradient of the neuron's output with respect to the neuron's weights.

# %%
#ANSQ3
def sse(output, target):
    return 0.5*(output - target)**2

def gradSse(output, target):
    return output-target

def neuron(weights, inputs):
    return sigma(weights.dot(inputs))

def gradNeuron(weights, inputs):
    return gradSigma(weights.dot(inputs))*inputs
#/ANSQ3

# %% [markdown]
# **Question 4 [10 credits]** Verify using finite differences that the gradients you implemented for the above functions is actually correct. To do this, we do a few runs with randomly sampled weights and inputs. In each run, compare the analytically computed gradient (the output of ``gradNeuron`` implemented above) with the result from finite differences (computed with ``neuron`` implemented above, and applying finite differences to the weights).

# %%
#ANSQ4

delta = 1e-5
for i in range(10):
    w = np.random.randn(5)
    x = np.random.randn(5)
    
    # (f(x+h)-f(x-h))/(2h)

    # Your code comes here...
    gw = [(neuron(w+delta*np.array([0 if i!=j else 1 for j in range(len(w))]), x)-neuron(w-delta*np.array([0 if i!=j else 1 for j in range(len(w))]),x))/(2*delta) for i in range(len(w))]
    print ("FD:       ", gw)
    print ("Analytical", gradNeuron(w,x))
    print (" -- DIFF  ", gw-gradNeuron(w,x))
    
#/ANSQ4
# Out:
# FD:        [-0.04913192408473321, 0.05644135286225759, -0.046000623214748064, -0.13792287451713792, 0.049593501551259404]
# Analytical [-0.04913192  0.05644135 -0.04600062 -0.13792287  0.0495935 ]
#  -- DIFF   [ 4.56495952e-13 -7.84830534e-13 -8.25665925e-13  1.25968680e-12
#   2.04933293e-13]
# FD:        [0.061652146619850516, 0.05019356954932829, -0.23972788662923736, 0.044441095450875594, 0.18639051259233816]
# Analytical [ 0.06165215  0.05019357 -0.23972789  0.0444411   0.18639051]
#  -- DIFF   [-1.42605372e-12  5.22547283e-13  4.96852559e-13  1.57064639e-12
#   3.35551031e-12]
# FD:        [0.41737662483665167, -0.13894176785211876, 0.29171944258832294, 0.49951531077285777, 0.03316233574690575]
# Analytical [ 0.41737662 -0.13894177  0.29171944  0.49951531  0.03316234]
#  -- DIFF   [-5.48322499e-12  9.15489906e-13 -4.99633668e-12 -1.36285982e-11
#   3.02900066e-12]
# FD:        [-0.05881435943821955, 0.11097435055895664, -0.1446280426253832, -0.39024455027458765, 0.43646161644317333]
# Analytical [-0.05881436  0.11097435 -0.14462804 -0.39024455  0.43646162]
#  -- DIFF   [ 1.65494007e-12  8.93896068e-13  6.95554725e-13  7.30837613e-12
#  -1.29827815e-11]
# FD:        [-0.09986720202748155, 0.015076271486780255, -0.137685782715391, 0.04342715290012177, -0.042228106701680534]
# Analytical [-0.0998672   0.01507627 -0.13768578  0.04342715 -0.04222811]
#  -- DIFF   [-4.74037476e-13 -1.20162214e-12 -6.75182132e-13 -9.08995101e-14
#  -2.50008347e-14]
# FD:        [-0.048992786821910876, 0.07412402394102457, 0.22945495007919978, 0.2009265155922257, 0.04398492615131921]
# Analytical [-0.04899279  0.07412402  0.22945495  0.20092652  0.04398493]
#  -- DIFF   [-2.25369723e-12 -3.71348785e-12  6.92979008e-12  8.14551204e-12
#  -2.07645706e-12]
# FD:        [0.027991307651603622, -0.01103741249786072, 0.08940819527583631, 0.2342556351349334, -0.06100780550744033]
# Analytical [ 0.02799131 -0.01103741  0.0894082   0.23425564 -0.06100781]
#  -- DIFF   [1.17511556e-12 1.60895776e-12 9.03860320e-13 6.93109459e-12
#  6.98385794e-13]
# FD:        [0.00145913375271256, -0.0011403901878370704, 0.004805137759911204, -0.0009110358467623313, -0.0006929056550752931]
# Analytical [ 0.00145913 -0.00114039  0.00480514 -0.00091104 -0.00069291]
#  -- DIFF   [ 8.55535261e-13  5.52563138e-12 -5.02236534e-12  4.62573686e-12
#  -9.59103565e-13]
# FD:        [-0.004765862865463433, 0.0008398921003127667, -0.009270995615651145, -0.03950101588601207, -0.009183639826382262]
# Analytical [-0.00476586  0.00083989 -0.009271   -0.03950102 -0.00918364]
#  -- DIFF   [-5.89746741e-12 -4.17423843e-12 -1.30195334e-12 -1.06804912e-11
#  -1.20788761e-11]
# FD:        [0.08168658445217858, -0.05364978885036286, 0.03367891113770227, 0.06147549980184407, -0.030314659735242163]
# Analytical [ 0.08168658 -0.05364979  0.03367891  0.0614755  -0.03031466]
#  -- DIFF   [ 1.81912818e-12 -1.17204857e-13 -1.07122644e-12 -8.23154045e-13
#   1.38271339e-12]

# %% [markdown]
# ### Training a single neuron
#
# We now have the code to implement gradient descent on a single neuron. We simply need to apply the chain rule of derivation to get the complete gradient.
#
# **Question 5 [10 marks]**
# Implement the error function and the gradient of the error function with respect to the weights. Then use the ```gradDesc``` function (provided in the top code box) to perform gradient descent and optimise the weights based on the provided data. Plot the evolution of the error in one plot, and the function that the neuron implements overlayed with the training data (in another plot)

# %%
data = np.load("curve.npz")
train = np.array([data['train'][:,0]]).T
traint = data['train'][:,1]
target = traint
print(train, target)
# Out:
# [[0.      ]
#  [0.111111]
#  [0.222222]
#  [0.333333]
#  [0.444444]
#  [0.555556]
#  [0.666667]
#  [0.777778]
#  [0.888889]
#  [1.      ]] [ 0.349486  0.830839  1.007332  0.971507  0.133066  0.166823 -0.848307
#  -0.445686 -0.563567  0.261502]

# %%
#ANSQ5
# Start by augmenting the data with a 1 so that w[0] is the bias
X = np.ones((train.shape[0],2))
X[:,1] = train[:,0]

def error_f(weight_l):
    input_ll, target_l = X, target
    error = 0
    for input_l, t in zip(input_ll, target_l):
        error+=((neuron(weight_l, input_l))-t)**2
    return 0.5*error


def grad_error_f(weight_l):
    input_ll, target_l = X, target
    grad = np.array([0.,0.])
    for input_l, t in zip(input_ll, target_l):
        step =(neuron(weight_l, input_l)-t) * gradNeuron(weight_l, input_l)
        grad += step
    return grad




w_0 = np.array([0.,0.])
w, errs, ts = gradDesc(w_0, errorfn=error_f, gradfn=grad_error_f)

plt.plot(errs)
plt.show()
x_values = np.linspace(0.,1.,100)
plt.plot(x_values, np.array([neuron(w,[1.,i]) for i in x_values]), 'r')
plt.scatter(train, target)
plt.legend(['Prediction','Learning data'])
#/ANSQ5
# Out:
# ## 0 err: 3.3788854137065 eta: 0.001 w: [0. 0.]
#   Gradient: [-0.02076657  0.00577496]
# ## 88 err: 0.9823625076191109 eta: 9.070885721119737 w: [  4.62776598 -11.88812314]
#   Gradient: [0.00554283 0.01722738]
# ## 89 err: 0.9807828414067855 eta: 10.885062865343684 w: [  4.57748765 -12.04439072]
#   Gradient: [-0.01702895  0.0069003 ]
# ## 90 err: 0.9792957050252996 eta: 13.062075438412421 w: [  4.76284886 -12.11950096]
#   Gradient: [0.01166716 0.01933539]
# ## 91 err: 0.9791459822610221 eta: 15.674490526094905 w: [  4.61045156 -12.37206128]
#   Gradient: [-0.03638694 -0.00212851]
# ## 92 err: 0.9764288163067941 eta: 9.404694315656943 w: [  4.8956249  -12.35537959]
#   Gradient: [0.01684191 0.02102587]
# ## 93 err: 0.9751754118899385 eta: 11.285633178788332 w: [  4.73723186 -12.55312146]
#   Gradient: [-0.02757091  0.0012114 ]
# ## 94 err: 0.9749282168360508 eta: 13.542759814545999 w: [  5.048387   -12.56679283]
#   Gradient: [0.02761815 0.02531567]
# ## 95 err: 0.9717465847554245 eta: 8.125655888727598 w: [  4.86137404 -12.73821485]
#   Gradient: [-0.01961848  0.00419582]
# ## 96 err: 0.970321799166746 eta: 9.750787066473118 w: [  5.02078705 -12.77230866]
#   Gradient: [0.00595764 0.01517621]
# ## 97 err: 0.9690789213201288 eta: 11.70094447976774 w: [  4.9626954  -12.92028867]
#   Gradient: [-0.01550759  0.00556281]
# ## 98 err: 0.9679551969632099 eta: 14.041133375721287 w: [  5.1441489  -12.98537886]
#   Gradient: [0.01125234 0.0170075 ]
# ## 99 err: 0.9665476977864778 eta: 8.424680025432773 w: [  5.06515109 -13.10478111]
#   Gradient: [-0.01143755  0.00691619]

# %% [markdown]
# ## Defining and training a network
#
# First, let us have a look at the implementation of the error and activation functions. As you have noticed above, there is a lot of duplicated code between the functions and their gradient and, therefore, a lot of wasted computation. We can reduce this problem by implementing functions that return both the computed function value and the value of the gradient for a given input. Here are a few examples of such implementations

# %%
# This code is given
# The following functions are activation functions. For efficiency, they combine the computation of 
# the activation function itself and its gradient wrt its input values, as both often rely on computing 
# the same intermediate quantities

def ssegf(y,t):
    '''Error and gradient function for sum-of-squares'''
    d = (y-t)
    return .5*d**2, d

def linvgf(a):
    '''Value and gradient function for linear activation'''
    return a,np.ones(a.shape)

def logitvgf(a):
    '''Error and gradient function for logit (sigmoidal)'''
    s = sigma(a)
    return s, s*(1-s)

def tanh(a):
    if a<-40:
        return -1.
    if a>40:
        return 1.
    ez = np.exp(a)
    emz = np.exp(-a)
    th = (ez-emz)/(ez+emz)
    return th    
tanh = np.vectorize(tanh)

def tanhvgf(a):
    '''Error and gradient function for hyperbolic tangent'''
    t = tanh(a)
    return t,1.-t*t

alpha = 1e-5
def symrelu_vgf(a):
    if a < -5:
        return alpha,-1+alpha*(a+5)
    if a > 5:
        return alpha,1+alpha*(a-5)
    return .2,.2*a
symreluvgf = np.vectorize(symrelu_vgf)

def reluvgf(a):
    if a<0.:
        return 0.,0.
    return 1.,a
reluvgf=np.vectorize(reluvgf)

x = np.linspace(-10,10,5000)
g,v = symreluvgf(x)
plt.plot(x,v,x,g)
# Out:
# [<matplotlib.lines.Line2D at 0x19428f4f048>,
#  <matplotlib.lines.Line2D at 0x19428f4f1d0>]

# %% [markdown]
# We define a feed-forward neural network using the following information:
# 1. The number of layers in the network
# 1. The number of nodes in each layer
# 1. The activation function used in each layer (notice that all nodes in a layer use the same activation function)
#
# The important thing to notice in such a network, is that the input of the nodes in layer $n$ are the outputs of the nodes in layer $n-1$, so that we have a chaining of functions and the chain rule of derivatives applies directly. We can, therefore, apply the chain rule mechanically and compute the gradient using a combination of the forward-propagated inputs and backward-propagated errors.
#
# The code below implements a neural network with arbitrary numbers of hidden nodes, arbitrary numbers of hidden layers, and arbitrary activation functions. Do look at the code and make sure you understand how it works, and how to use it.

# %%
class NN:
    '''Implementation of an artificial neural network'''
    def __init__(self, nIn, nodesPerLayer, actFn):
        '''Initialise the network with random weights and biases. 
        Parameters are:
        nIn: Number of input nodes (dimensionality of the data)
        nodePerLayer: Tuple of numbers of hidden nodes, one integer per layer, including the output layer
        actFn: Tuple of activation functions; one function per computational layer (hidden or output)'''
        
        assert(len(nodesPerLayer) == len(actFn))  # Check that the parameters are consistent
        
        self.numNodes = [nIn]                     # Create a list of numbers of nodes per layer
        if nodesPerLayer:
            self.numNodes.extend(nodesPerLayer)
        self.reinit()
        self.actfn = actFn
        
    def reinit(self,eta=1.0):
        '''Re-initialise weights with random values'''
        # Initialise weights and biases
        self.w = [ eta * np.random.randn(self.numNodes[i],self.numNodes[i-1]) for i in range(1,len(self.numNodes)) ]
        # print "Weights", self.w
        self.biases = [ eta * np.random.randn(self.numNodes[i]) for i in range(1,len(self.numNodes))]
        # print "Biases:", self.biases
        
    def forward(self,x):
        ''' Compute the activations of the nodes of each layer.
            For efficiency, use "VGF" functions and store the gradient of the activation function as well. In
            other words each entry of self.fw is a tuple containing (z_i, h'(a_i))
        '''
        self.fw = [ self.actfn[0](self.w[0].dot(x) + self.biases[0]) ]  # First layer takes data as input
        for h,w,b in zip(self.actfn[1:],self.w[1:],self.biases[1:]):    # following layers take the output of  
            self.fw.append(h(w.dot(self.fw[-1][0]) + b))                #    the previous layer
        return self.fw[-1][0]
    
    def back(self, errorgrad):
        '''Implement backpropagation of the errors'''
        self.delta = [ self.fw[-1][1] * errorgrad ]             # Start with the gradient of the error function
        
        for layer in range(len(self.w)-1,0,-1):
            hprime = self.fw[layer-1][1]                        # h'(a_j)
            #delta = self.delta[0]                               # list gets extended at start, first elt: delta_k
            w = self.w[layer]                                   # w_kj

            self.delta.insert(0,hprime * (self.delta[0].dot(w))) # Use dot product to sum over all FOLLOWING weights        

    def gradients(self, x, t, eta=1e-3):
        '''Compute the gradients of the error of a single datapoint, with respect to
        all weights and all biases'''
        y = self.forward(x)                        # Forward propagation and computation of h'
        error = y-t
        self.back(error)                           # Backward propagation
                              
        gradw = []
        gradb = []
        gradw.append(np.outer(self.delta[0],x))    # derivative wrt w_ji = delta_j z_i, where z_i == x_i for input nodes
        gradb.append(self.delta[0])                #    and z_i == 1 for bias nodes
        
        for i in range(1,len(self.w)):
            gradw.append(np.outer(self.delta[i],self.fw[i-1][0])) # for folloing layers, use output of previous layer
            gradb.append(self.delta[i])
        return gradw,gradb,.5*error*error          # Return gradient wrt w and bias, and the error

    def batchGradients(self, data,targets):
        '''Compute the gradients of all weights and biases, for the complete dataset'''                      
        gradw,gradb,error = self.gradients(data[0,:],targets[0])
        for x,t in zip(data[1:,:],targets[1:]):
            tw,tb,e = self.gradients(x,t)
            error += e
            for i in range(len(gradw)):
                gradw[i] += tw[i]
                gradb[i] += tb[i]
        return gradw,gradb,error
    
    def batchStep(self,data,targets,eta=1e-3):
        '''Make one step of batch gradient descent'''
        gw,gb,e = self.batchGradients(data,targets)
        for i in range(len(gw)):
            self.w[i] -= eta*gw[i]
            self.biases[i] -= eta*gb[i]
        return e
       
    def train(self,data,targets,eta=1e-4, minit=100, maxit=10000):
        '''Train the network using batch GD'''
        es = np.zeros(maxit)
        for i in range(maxit):
            es[i] = self.batchStep(data,targets,eta)
            if i>minit and es[i-1]< es[i]+1e-5:
                return es[:i+1]
        return es

# %% [markdown]
# Using the above code, let's create a neural network with one layer with hyperbolic tangent activation function, and one output node with linear output activation function, and train it on the provided data. We plot the evolution of the training error, as well as the function that the neural network implements (in two separate plots).

# %%
net = NN(1,(10,1),(tanhvgf,linvgf,))
net.reinit(eta=1.)
errors = net.train(train,traint,1e-2,minit=100,maxit=10000)
plt.plot(errors)
plt.figure()
plt.scatter(train,traint)
x = np.arange(0,1,.01)
y = np.array([float(net.forward([d])) for d in x])
plt.plot(x,y)
#print (net.w)
#print (net.biases)

# %% [markdown]
# **Question 6 [30 credits]** Use the provided test data to compare this to other configurations of your choice (more hidden layers, different activation functions, ...). Find a network that performs well on the given data. Perform multiple training runs with random initialisations, plot the final validation error for each run in function of the number of nodes, and keep the best. Plot the train and test data, as well as the function implemented by your final network

# %%
test = np.array([data['test'][:,0]]).T
testt = data['test'][:,1]

# %%
#ANSQ6
import itertools as it

def evaluateNet(net):
    err = 0.
    for x,t in zip(test,testt):
        err += sse(net.forward(x),t)
    return err

    

act_functions = [linvgf, logitvgf, tanhvgf]
nb_nodes = [1, 3, 5, 7, 10, 50]
max_hidden_layer = 3

n_l = []
e_l = []
v_l = []

for l in range(1, max_hidden_layer+1):
    for n_layer_t in it.combinations_with_replacement(nb_nodes, l):
        for f_layer_t in it.combinations_with_replacement(act_functions, l):
            node_layer_t = [n for n in n_layer_t]+[1]
            function_layer_t = [n for n in f_layer_t]+[linvgf]
            
            net = NN(1, node_layer_t, function_layer_t)
            net.reinit(eta=1.)
            error_train = net.train(train,traint,1e-2,minit=100,maxit=10000)
            error_valid = evaluateNet(net)
            
            print('N:{}, F:{}\tTrain: {}, Validation: {}'.format(node_layer_t, [f.__name__ for f in function_layer_t], error_train[-1], error_valid))
            
            if np.isnan(error_valid[0]): continue
            n_l+=[net]
            e_l+=[error_train]
            v_l+=[error_valid[0]]



#/ANSQ6
# Out:
# N:[1, 1], F:['linvgf', 'linvgf']	Train: 1.0684666360546857, Validation: [1.53230385]
# N:[1, 1], F:['logitvgf', 'linvgf']	Train: 0.8645043969516429, Validation: [1.2479082]
# N:[1, 1], F:['tanhvgf', 'linvgf']	Train: 0.6383425615682894, Validation: [0.93841402]
# N:[3, 1], F:['linvgf', 'linvgf']	Train: 1.0684703506140074, Validation: [1.5316014]
# N:[3, 1], F:['logitvgf', 'linvgf']	Train: 0.5558518787098414, Validation: [0.88038229]
# N:[3, 1], F:['tanhvgf', 'linvgf']	Train: 0.3052919147524204, Validation: [0.50620501]
# N:[5, 1], F:['linvgf', 'linvgf']	Train: 1.0683561300369657, Validation: [1.53131959]
# N:[5, 1], F:['logitvgf', 'linvgf']	Train: 0.6507397019368476, Validation: [0.99998959]
# N:[5, 1], F:['tanhvgf', 'linvgf']	Train: 0.18884531383344147, Validation: [0.38395229]
# N:[7, 1], F:['linvgf', 'linvgf']	Train: 1.068270336044673, Validation: [1.52832261]
# N:[7, 1], F:['logitvgf', 'linvgf']	Train: 1.0404811527708366, Validation: [1.49460562]
# N:[7, 1], F:['tanhvgf', 'linvgf']	Train: 0.2130912744652403, Validation: [0.40185068]
# N:[10, 1], F:['linvgf', 'linvgf']	Train: 1.0682704276222819, Validation: [1.52839063]
# N:[10, 1], F:['logitvgf', 'linvgf']	Train: 1.0469446104458073, Validation: [1.50634214]
# N:[10, 1], F:['tanhvgf', 'linvgf']	Train: 0.2077532831320634, Validation: [0.42464238]
# C:\Anaconda3\envs\BML_LAB\lib\site-packages\numpy\core\numeric.py:1129: RuntimeWarning: invalid value encountered in multiply
#   return multiply(a.ravel()[:, newaxis], b.ravel()[newaxis, :], out)
# C:\Anaconda3\envs\BML_LAB\lib\site-packages\numpy\core\numeric.py:1129: RuntimeWarning: overflow encountered in multiply
#   return multiply(a.ravel()[:, newaxis], b.ravel()[newaxis, :], out)
# C:\Anaconda3\envs\BML_LAB\lib\site-packages\ipykernel_launcher.py:62: RuntimeWarning: overflow encountered in multiply
# N:[50, 1], F:['linvgf', 'linvgf']	Train: nan, Validation: [nan]
# N:[50, 1], F:['logitvgf', 'linvgf']	Train: 1.0658900273180598, Validation: [1.52419816]
# N:[50, 1], F:['tanhvgf', 'linvgf']	Train: 9.007383563150082e+120, Validation: [1.51414118e+122]
# N:[1, 1, 1], F:['linvgf', 'linvgf', 'linvgf']	Train: 1.0685864382009727, Validation: [1.53151145]
# N:[1, 1, 1], F:['linvgf', 'logitvgf', 'linvgf']	Train: 0.5991541916730828, Validation: [0.87399914]
# N:[1, 1, 1], F:['linvgf', 'tanhvgf', 'linvgf']	Train: 0.5948192028077675, Validation: [0.86410693]
# N:[1, 1, 1], F:['logitvgf', 'logitvgf', 'linvgf']	Train: 0.787811520846374, Validation: [1.13921005]
# N:[1, 1, 1], F:['logitvgf', 'tanhvgf', 'linvgf']	Train: 0.6623943680386356, Validation: [0.96058677]
# N:[1, 1, 1], F:['tanhvgf', 'tanhvgf', 'linvgf']	Train: 0.6045664145217877, Validation: [0.86752903]
# N:[1, 3, 1], F:['linvgf', 'linvgf', 'linvgf']	Train: 1.0683343229368094, Validation: [1.53148926]
# N:[1, 3, 1], F:['linvgf', 'logitvgf', 'linvgf']	Train: 0.23271561525332632, Validation: [0.46691442]
# N:[1, 3, 1], F:['linvgf', 'tanhvgf', 'linvgf']	Train: 1.0692445003451623, Validation: [1.5257923]
# N:[1, 3, 1], F:['logitvgf', 'logitvgf', 'linvgf']	Train: 0.8135600783665599, Validation: [1.17204124]
# N:[1, 3, 1], F:['logitvgf', 'tanhvgf', 'linvgf']	Train: 0.4338939321335942, Validation: [0.59766276]
# N:[1, 3, 1], F:['tanhvgf', 'tanhvgf', 'linvgf']	Train: 0.43801422285216796, Validation: [0.60346738]
# N:[1, 5, 1], F:['linvgf', 'linvgf', 'linvgf']	Train: 1.068355978356788, Validation: [1.53077384]
# N:[1, 5, 1], F:['linvgf', 'logitvgf', 'linvgf']	Train: 0.28033858918656085, Validation: [0.4923568]
# N:[1, 5, 1], F:['linvgf', 'tanhvgf', 'linvgf']	Train: 0
 50, 1], F:['linvgf', 'linvgf', 'logitvgf', 'linvgf']	Train: 9.558190544736993e+21, Validation: [1.37637944e+22]
# N:[1, 50, 50, 1], F:['linvgf', 'linvgf', 'tanhvgf', 'linvgf']	Train: 1.0531605630803019e+124, Validation: [1.77036291e+125]
# N:[1, 50, 50, 1], F:['linvgf', 'logitvgf', 'logitvgf', 'linvgf']	Train: 0.16824819934711893, Validation: [0.38161153]
# N:[1, 50, 50, 1], F:['linvgf', 'logitvgf', 'tanhvgf', 'linvgf']	Train: 1.3511824406122841e+124, Validation: [2.27133768e+125]
# N:[1, 50, 50, 1], F:['linvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 4.559456132697805e+121, Validation: [7.66444576e+122]
# N:[1, 50, 50, 1], F:['logitvgf', 'logitvgf', 'logitvgf', 'linvgf']	Train: 0.4859565466778625, Validation: [0.66231128]
# N:[1, 50, 50, 1], F:['logitvgf', 'logitvgf', 'tanhvgf', 'linvgf']	Train: 8.790051542566428e+123, Validation: [1.47760766e+125]
# N:[1, 50, 50, 1], F:['logitvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 7.972082961843041e+122, Validation: [1.34010715e+124]
# N:[1, 50, 50, 1], F:['tanhvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 3.1878774549314276e+118, Validation: [5.358822e+119]
# N:[3, 3, 3, 1], F:['linvgf', 'linvgf', 'linvgf', 'linvgf']	Train: nan, Validation: [nan]
# N:[3, 3, 3, 1], F:['linvgf', 'linvgf', 'logitvgf', 'linvgf']	Train: 0.4376949996362911, Validation: [0.59599955]
# N:[3, 3, 3, 1], F:['linvgf', 'linvgf', 'tanhvgf', 'linvgf']	Train: 0.4348527179253254, Validation: [0.59018803]
# N:[3, 3, 3, 1], F:['linvgf', 'logitvgf', 'logitvgf', 'linvgf']	Train: 1.8969063351721538, Validation: [2.68198608]
# N:[3, 3, 3, 1], F:['linvgf', 'logitvgf', 'tanhvgf', 'linvgf']	Train: 0.18986404955577774, Validation: [0.39960332]
# N:[3, 3, 3, 1], F:['linvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 0.35971698082696585, Validation: [0.4818741]
# N:[3, 3, 3, 1], F:['logitvgf', 'logitvgf', 'logitvgf', 'linvgf']	Train: 0.6702444979583961, Validation: [0.97608809]
# N:[3, 3, 3, 1], F:['logitvgf', 'logitvgf', 'tanhvgf', 'linvgf']	Train: 0.42915562519494044, Validation: [0.60361535]
# N:[3, 3, 3, 1], F:['logitvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 1.0441617754886783, Validation: [1.49410313]
# N:[3, 3, 3, 1], F:['tanhvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 0.3309421615366673, Validation: [0.68280933]
# N:[3, 3, 5, 1], F:['linvgf', 'linvgf', 'linvgf', 'linvgf']	Train: nan, Validation: [nan]
# N:[3, 3, 5, 1], F:['linvgf', 'linvgf', 'logitvgf', 'linvgf']	Train: 0.4364061120485908, Validation: [0.59575138]
# N:[3, 3, 5, 1], F:['linvgf', 'linvgf', 'tanhvgf', 'linvgf']	Train: 0.4108861474435116, Validation: [0.59019256]
# N:[3, 3, 5, 1], F:['linvgf', 'logitvgf', 'logitvgf', 'linvgf']	Train: 0.2015451167001065, Validation: [0.42681185]
# N:[3, 3, 5, 1], F:['linvgf', 'logitvgf', 'tanhvgf', 'linvgf']	Train: 0.23251978967058407, Validation: [0.42158867]
# N:[3, 3, 5, 1], F:['linvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 1.0442163616088471, Validation: [1.44167264]
# N:[3, 3, 5, 1], F:['logitvgf', 'logitvgf', 'logitvgf', 'linvgf']	Train: 0.5231754382599823, Validation: [0.80694219]
# N:[3, 3, 5, 1], F:['logitvgf', 'logitvgf', 'tanhvgf', 'linvgf']	Train: 0.4473752054379043, Validation: [0.71395442]
# N:[3, 3, 5, 1], F:['logitvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 1.066542759060698, Validation: [1.4481135]
# N:[3, 3, 5, 1], F:['tanhvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 0.46199535873731534, Validation: [0.77210545]
# N:[3, 3, 7, 1], F:['linvgf', 'linvgf', 'linvgf', 'linvgf']	Train: nan, Validation: [nan]
# N:[3, 3, 7, 1], F:['linvgf', 'linvgf', 'logitvgf', 'linvgf']	Train: 0.1854372373961225, Validation: [0.39206555]
# N:[3, 3, 7, 1], F:['linvgf', 'linvgf', 'tanhvgf', 'linvgf']	Train: 1.0164302857678216, Validation: [1.56788188]
# N:[3, 3, 7, 1], F:['linvgf', 'logitvgf', 'logitvgf', 'linvgf']	Train: 0.1925607256521371, Validation: [0.40634125]
# N:[3, 3, 7, 1], F:['linvgf', 'logitvgf', 'tanhvgf', 'linvgf']	Train: 0.1823461454482119, Validation: [0.38543326]
# N:[3, 3, 7, 1], F:['linvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 1.10008210520675, Validation: [1.61526659]
# N:[3, 3, 7, 1], F:['logitvgf', 'logitvgf', 'logitvgf', 'linvgf']	Train: 0.5603914103740019, Validation: [0.83503058]
# N:[3, 3, 7, 1], F:['logitvgf', 'logitvgf', 'tanhvgf', 'linvgf']	Train: 1.028000993007616, Validation: [1.467771]
# N:[3, 3, 7, 1], F:['logitvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 0.18498945657958166, Validation: [0.38399663]
# N:[3, 3, 7, 1], F:['tanhvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 0.20866752939778557, Validation: [0.47419425]
# N:[3, 3, 10, 1], F:['linvgf', 'linvgf', 'linvgf', 'linvgf']	Train: nan, Validation: [nan]
# N:[3, 3, 10, 1], F:['linvgf', 'linvgf', 'logitvgf', 'linvgf']	Train: 0.050093550836182214, Validation: [0.58104643]
# N:[3, 3, 10, 1], F:['linvgf', 'linvgf', 'tanhvgf', 'linvgf']	Train: 0.23678939159407036, Validation: [0.59906258]
# N:[3, 3, 10, 1], F:['linvgf', 'logitvgf', 'logitvgf', 'linvgf']	Train: 0.33224368703120355, Validation: [0.67891182]
# N:[3, 3, 10, 1], F:['linvgf', 'logitvgf', 'tanhvgf', 'linvgf']	Train: 0.29895444557408646, Validation: [0.4413986]
# N:[3, 3, 10, 1], F:['linvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 0.24736645218911013, Validation: [0.5622522]
# N:[3, 3, 10, 1], F:['logitvgf', 'logitvgf', 'logitvgf', 'linvgf']	Train: 0.3545928854681738, Validation: [0.69167991]
# N:[3, 3, 10, 1], F:['logitvgf', 'logitvgf', 'tanhvgf', 'linvgf']	Train: 1.1150555734721752, Validation: [1.57965528]
# N:[3, 3, 10, 1], F:['logitvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 0.18286969677238896, Validation: [0.38763174]
# N:[3, 3, 10, 1], F:['tanhvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 0.17288395016859343, Validation: [0.35366772]
# N:[3, 3, 50, 1], F:['linvgf', 'linvgf', 'linvgf', 'linvgf']	Train: nan, Validation: [nan]
# N:[3, 3, 50, 1], F:['linvgf', 'linvgf', 'logitvgf', 'linvgf']	Train: 2.2697470729694555, Validation: [3.3298762]
# N:[3, 3, 50, 1], F:['linvgf', 'linvgf', 'tanhvgf', 'linvgf']	Train: 3.0697000263903025e+119, Validation: [5.16016574e+120]
# N:[3, 3, 50, 1], F:['linvgf', 'logitvgf', 'logitvgf', 'linvgf']	Train: 0.2334576046849708, Validation: [0.47108444]
# N:[3, 3, 50, 1], F:['linvgf', 'logitvgf', 'tanhvgf', 'linvgf']	Train: 5.612851608099712e+118, Validation: [9.43520355e+119]
# N:[3, 3, 50, 1], F:['linvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 2.839846676162653e+121, Validation: [4.77378226e+122]
# N:[3, 3, 50, 1], F:['logitvgf', 'logitvgf', 'logitvgf', 'linvgf']	Train: 1.0187111434196991, Validation: [1.47283176]
# N:[3, 3, 50, 1], F:['logitvgf', 'logitvgf', 'tanhvgf', 'linvgf']	Train: 2.854513917634892e+119, Validation: [4.7984379e+120]
# N:[3, 3, 50, 1], F:['logitvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 1.0024883796379087e+122, Validation: [1.68518297e+123]
# N:[3, 3, 50, 1], F:['tanhvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 3.6785454868074415e+121, Validation: [6.18363496e+122]
# N:[3, 5, 5, 1], F:['linvgf', 'linvgf', 'linvgf', 'linvgf']	Train: nan, Validation: [nan]
# N:[3, 5, 5, 1], F:['linvgf', 'linvgf', 'logitvgf', 'linvgf']	Train: 0.17733569970974833, Validation: [0.36918735]
# N:[3, 5, 5, 1], F:['linvgf', 'linvgf', 'tanhvgf', 'linvgf']	Train: 1.3630183066876922, Validation: [2.81329515]
# N:[3, 5, 5, 1], F:['linvgf', 'logitvgf', 'logitvgf', 'linvgf']	Train: 0.20480569456763933, Validation: [0.42124009]
# N:[3, 5, 5, 1], F:['linvgf', 'logitvgf', 'tanhvgf', 'linvgf']	Train: 0.2678718642965532, Validation: [0.45520261]
# N:[3, 5, 5, 1], F:['linvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 1.0474793793954893, Validation: [1.23916856]
# N:[3, 5, 5, 1], F:['logitvgf', 'logitvgf', 'logitvgf', 'linvgf']	Train: 0.6381899587821313, Validation: [0.92316338]
# N:[3, 5, 5, 1], F:['logitvgf', 'logitvgf', 'tanhvgf', 'linvgf']	Train: 0.2730083720512703, Validation: [0.57812027]
# N:[3, 5, 5, 1], F:['logitvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 0.603524462597741, Validation: [0.86611853]
# N:[3, 5, 5, 1], F:['tanhvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 0.34294400175858764, Validation: [0.69395983]
# N:[3, 5, 7, 1], F:['linvgf', 'linvgf', 'linvgf', 'linvgf']	Train: nan, Validation: [nan]
# N:[3, 5, 7, 1], F:['linvgf', 'linvgf', 'logitvgf', 'linvgf']	Train: 0.18994784776428153, Validation: [0.39778309]
# N:[3, 5, 7, 1], F:['linvgf', 'linvgf', 'tanhvgf', 'linvgf']	Train: 1.1504691727421663, Validation: [1.9544528]
# N:[3, 5, 7, 1], F:['linvgf', 'logitvgf', 'logitvgf', 'linvgf']	Train: 0.19724411336022032, Validation: [0.40983262]
# N:[3, 5, 7, 1], F:['linvgf', 'logitvgf', 'tanhvgf', 'linvgf']	Train: 1.0394720174256131, Validation: [1.62986915]
# N:[3, 5, 7, 1], F:['linvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 0.17182205678709317, Validation: [0.36711554]
# N:[3, 5, 7, 1], F:['logitvgf', 'logitvgf', 'logitvgf', 'linvgf']	Train: 0.4870546910774487, Validation: [0.73033172]
# N:[3, 5, 7, 1], F:['logitvgf', 'logitvgf', 'tanhvgf', 'linvgf']	Train: 1.1016224780249801, Validation: [1.58443088]
# N:[3, 5, 7, 1], F:['logitvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 0.18496996276338137, Validation: [0.39714344]
# N:[3, 5, 7, 1], F:['tanhvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 0.18596662050422927, Validation: [0.38080632]
# N:[3, 5, 10, 1], F:['linvgf', 'linvgf', 'linvgf', 'linvgf']	Train: nan, Validation: [nan]
# N:[3, 5, 10, 1], F:['linvgf', 'linvgf', 'logitvgf', 'linvgf']	Train: 0.011079906689235584, Validation: [0.60992741]
# N:[3, 5, 10, 1], F:['linvgf', 'linvgf', 'tanhvgf', 'linvgf']	Train: 0.4492460956711821, Validation: [1.02505201]
# N:[3, 5, 10, 1], F:['linvgf', 'logitvgf', 'logitvgf', 'linvgf']	Train: 0.18797816653887992, Validation: [0.40026887]
# N:[3, 5, 10, 1], F:['linvgf', 'logitvgf', 'tanhvgf', 'linvgf']	Train: 0.21494203033782194, Validation: [0.4404637]
# N:[3, 5, 10, 1], F:['linvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 0.22757877587569902, Validation: [0.49423236]
# N:[3, 5, 10, 1], F:['logitvgf', 'logitvgf', 'logitvgf', 'linvgf']	Train: 0.7718365476815869, Validation: [1.12276425]
# N:[3, 5, 10, 1], F:['logitvgf', 'logitvgf', 'tanhvgf', 'linvgf']	Train: 1.0984488276013935, Validation: [1.71412139]
# N:[3, 5, 10, 1], F:['logitvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 1.0448723938007927, Validation: [1.44062038]
# N:[3, 5, 10, 1], F:['tanhvgf', 'tanhvgf', 'tanhvgf', 'linvgf']	Train: 0.1772241117373721, Validation: [0.36824231]
# N:[3, 5, 50, 1], F:['linvgf', 'linvgf', 'linvgf', 'linvgf']	Train: nan, Validation: [nan]
# ...
#        7.56284671e+005, 8.17087507e+006, 1.17457861e+008, 1.68147925e+009,
#        1.33304066e+123, 2.24084136e+124]), <__main__.NN object at 0x000001942C1246A0>), (2.0591986639011732e+126, array([4.39689131e+002, 6.60609299e+003, 1.05692149e+004, 1.61383222e+005,
#        2.50225246e+006, 2.92485964e+007, 4.56767075e+008, 7.66947209e+009,
#        1.28923826e+011, 2.16720951e+012, 3.64307919e+013, 6.12401611e+014,
#        1.02944711e+016, 1.73050059e+017, 2.90897149e+018, 4.88998108e+019,
#        8.22005819e+020, 1.38179178e+022, 2.32279199e+023, 3.90461333e+024,
#        6.56365500e+025, 1.10335041e+027, 1.85473203e+028, 3.11780455e+029,
#        5.24102944e+030, 8.81017049e+031, 1.48098966e+033, 2.48954362e+034,
#        4.18492282e+035, 7.03485526e+036, 1.18255917e+038, 1.98788196e+039,
#        3.34162958e+040, 5.61727933e+041, 9.44264655e+042, 1.58730889e+044,
#        2.66826624e+045, 4.48535554e+046, 7.53988267e+047, 1.26745428e+049,
#        2.13059064e+050, 3.58152286e+051, 6.02053993e+052, 1.01205276e+054,
#        1.70126069e+055, 2.85981923e+056, 4.80735612e+057, 8.08116564e+058,
#        1.35844394e+060, 2.28354427e+061, 3.83863792e+062, 6.45275034e+063,
#        1.08470733e+065, 1.82339303e+066, 3.06512368e+067, 5.15247290e+068,
#        8.66130694e+069, 1.45596570e+071, 2.44747834e+072, 4.11421108e+073,
#        6.91598883e+074, 1.16257772e+076, 1.95429315e+077, 3.28516679e+078,
#        5.52236537e+079, 9.28309619e+080, 1.56048847e+082, 2.62318112e+083,
#        4.40956746e+084, 7.41248290e+085, 1.24603837e+087, 2.09459051e+088,
#        3.52100664e+089, 5.91881217e+090, 9.94952326e+091, 1.67251486e+093,
#        2.81149748e+094, 4.72612726e+095, 7.94461993e+096, 1.33549061e+098,
#        2.24495971e+099, 3.77377728e+100, 6.34371961e+101, 1.06637927e+103,
#        1.79258355e+104, 3.01333294e+105, 5.06541267e+106, 8.51495871e+107,
#        1.43136456e+109, 2.40612382e+110, 4.04469415e+111, 6.79913086e+112,
#        1.14293390e+114, 1.92127188e+115, 3.22965803e+116, 5.42905515e+117,
#        9.12624171e+118, 1.53412123e+120, 2.57885779e+121, 4.33505995e+122,
#        7.28723577e+123, 1.22498433e+125]), <__main__.NN object at 0x00000194303AAA58>)]
# ********************
# Best model: Network: [1, 7, 7, 7, 1], using activation function: ['linvgf', 'tanhvgf', 'tanhvgf', 'linvgf'] with error on validation: 0.31109416705975235

# %%
results = list(zip(v_l, e_l, n_l))

results = sorted(results, key=lambda x: x[0])
#print(results)
print('*'*20)
print('Best model: Network: {}, using activation function: {} with error on validation: {}'.format(results[0][2].numNodes, [f.__name__ for f in results[0][2].actfn], results[0][0]))
errors = results[0][1]
net  = results[0][2]
plt.plot(errors)
plt.figure()
plt.scatter(train,traint)
plt.scatter(test, testt, color='r')
x = np.arange(0,1,.01)
y = np.array([float(net.forward([d])) for d in x])
plt.plot(x,y)
plt.legend(['prediction', 'train', 'test'])
plt.draw()
plt.show()
# Out:
# ********************
# Best model: Network: [1, 7, 7, 7, 1], using activation function: ['linvgf', 'tanhvgf', 'tanhvgf', 'linvgf'] with error on validation: 0.31109416705975235
